# %% [markdown]
# ## Check Python Version
# Check Your Python version before running this notebook.
# - Python 3.6.X is required to run this notebook.

# %%
import sys
import re

class PythonVersionException(Exception):
    pass;

if re.match('3.6*', sys.version.split('(')[0]) is None:
    print(sys.version.split('(')[0], ' Please use Python 3.6.X')
    raise PythonVersionException

# %% [markdown]
# ## Library imports
# Import all the library's required for this notebook.

# %%
import os
import os.path
import numpy as np
from collections import Counter
from nltk import word_tokenize, WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import cross_validate, cross_val_score, StratifiedKFold
from time import time
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt
import csv
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# ## NLTK Corpus Sets
# Run this section to check if the following corpus datasets have been downloaded, if they are missing this will download
# them for you.

# %%
import nltk
nltkDataDir = '../data/nltk_data'

nltk.data.path.append(os.path.abspath(nltkDataDir))

try:
    stopwords.words('english')
except(LookupError, OSError) as e:
    nltk.download('stopwords', nltkDataDir)

try:
    WordNetLemmatizer().lemmatize("testing")
except(LookupError, OSError) as e:
    nltk.download('punkt', nltkDataDir)
    nltk.download('wordnet', nltkDataDir)

# %%
stoplist = stopwords.words('english')

def enron_selector():  # function to identify platform and selected dataset to be applied.
    def init_lists(folder_collection, label):  # function to retrieve and apply email content to array.
        a_list = []
        doc_id = 0
        file_list = []
        label = "Loading " + label + "..."
        for entry in folder_collection:
            b_list = os.listdir(entry)
            for item in b_list:
                file_list.append(entry + item)
        for a_file in file_list:
            f = open(a_file, 'r')
            process_status(doc_id, file_list, label)
            try:
                a_list.append(f.read())
            except UnicodeDecodeError:
                pass
            doc_id += 1
        f.close()
        return a_list

    enron_ = ['Enron1/', 'Enron2/', 'Enron3/', 'Enron4/', 'Enron5/', 'Enron6/']
    spam = []
    ham = []

    for i, sub in enumerate(enron_):
        spam.append('../data/enron_dataset/Enron/Processed/' + enron_[i] + 'spam/')
        ham.append('../data/enron_dataset/Enron/Processed/' + enron_[i] + 'ham/')

    spam = init_lists(spam, "spam")
    ham = init_lists(ham, "ham")
    all_emails = [(email, 'spam') for email in spam]
    all_emails += [(email, 'ham') for email in ham]
    ham_emails, spam_emails = preprocess(all_emails)
    ham_file, spam_file = "../data/processed_ham.txt", "../data/processed_spam.txt"
    print("Writing ham file...")
    with open(ham_file, 'w') as fp:
        fp.write('\n'.join('{} {};'.format(x[0], x[1]) for x in ham_emails))
    print("Writing spam file...")
    with open(spam_file, 'w') as fp:
        fp.write('\n'.join('{} {};'.format(x[0], x[1]) for x in spam_emails))
    return ham_emails, spam_emails


def test_collection(test_select):  # function that outlines all tests to be carried out.
    if test_select == 1:
        data_size = 1000 / 2
    elif test_select == 2:
        data_size = 2000 / 2
    elif test_select == 3:
        data_size = 3000 / 2
    elif test_select == 4:
        data_size = 1500 / 2
    return data_size


def preprocess(sentence):  # function to apply pre-processing: stop words, lemmatise.
    lemmatizer = WordNetLemmatizer()
    label = 'Pre-processing emails...'
    entry_id = 0
    doc_id = 0
    processed = []
    length_items = len(sentence)
    for entry in sentence:
        process_status(doc_id, sentence, label)
        for i, line in enumerate(entry):
            emails = ''
            if i == 0:
                words = []
                for word in word_tokenize(line):
                    item = lemmatizer.lemmatize(word.lower())
                    if not item in stoplist:
                        if word.isalnum() == False:
                            pass
                        else:
                            emails = emails + item + ','
                processed.append(tuple((emails, entry[1])))
                del emails
                entry_id += 1
        doc_id += 1
    email_list = []
    ham = []
    spam = []
    for entry in processed:
        if entry[1] == 'ham':
            email_list.append(entry)
            ham.append(entry)
    for entry in processed:
        if entry[1] == 'spam':
            email_list.append(entry)
            spam.append(entry)
    return ham, spam


def make_dictionary(all_emails):  # function to create dictionary, removing html tags, non alpha items e.g. numbers.
    def html_list():
        html_tag_list = []
        location = '../data/html_tag_list.txt'
        f = open(location, 'r')
        for i in f:
            html_tag_list.append(i.strip())
        f.close()
        return html_tag_list

    html_tags = [html_list()]
    processed_emails = all_emails
    all_words = []
    for entry in all_emails:
        for sentence in entry:
            if not sentence == 'ham' or sentence == 'spam':
                words = str(sentence).split(',')
                for word in words:
                    all_words.append(word)
    dictionary = Counter(all_words)
    list_to_remove = list(dictionary)
    for item in list_to_remove:
        if len(item) <= 1:
            del dictionary[item]
        elif item in html_tags:
            del dictionary[item]
        elif str(item).isdigit():
            del dictionary[item]

    return dictionary


def dictionary_build(emails):
    print("Building Dictionary...")
    feature_dictionary = make_dictionary(emails)
    return feature_dictionary


def extract_features(data,
                     label):  # function to extrat features to martix based on calculating occurance of words based
    # on dictionary.
    features_matrix = np.zeros((len(data), len(dictionary)))
    label = 'Feature extraction \'' + label + '\':'
    doc_id = 0
    all_words = []
    for entry in data:
        process_status(doc_id, data, label)
        for i, line in enumerate(entry):
            if i == 0:
                # print('[' + str(doc_id) + '] ', entry)
                words = line.split(',')
                for word in words:
                    all_words.append(words)
                    for j, d in enumerate(dictionary):
                        if d[0] == word:
                            word_id = j
                            features_matrix[doc_id, word_id] = words.count(word)
        doc_id = doc_id + 1
    return features_matrix


def models(train_features, train_dev_features, test_features, train_labels, train_dev_labels, test_labels, model_process
           , feature_size, test_set):
    # function to hold classifiers, fit and prediction and finally report the performance based on return method.
    algorithm_names = ['k-Neighbors Classifier',
                       'MLP Neural Network 1',
                       'MLP Neural Network 2',
                       'Logistic Regression',
                       'Random Forest',
                       'xgBoost',
                       'Multinomial Naive Bayes',
                       'Gaussian NB',
                       'Bernoulli NB',
                       'Rbf SVC',
                       'Linear SVC',
                       'Poly SVC',
                       'Sigmoid SVC']
    scoring = ['precision_macro', 'recall_macro', 'f1']
    scoring_parse_labels = ['fit_time', 'score_time', 'test_precision_macro', 'test_recall_macro', 'test_f1']

    print('Processing models...')

    model1 = KNeighborsClassifier(algorithm='brute')
    model2 = MLPClassifier(hidden_layer_sizes=75, solver='lbfgs', max_iter=25)
    model3 = MLPClassifier(hidden_layer_sizes=(150, 150), solver='lbfgs', max_iter=25)
    model4 = LogisticRegression(solver='lbfgs', max_iter=25)
    model5 = RandomForestClassifier(n_estimators=50, max_depth=None, min_samples_split=2, random_state=0)
    model6 = XGBClassifier()
    model7 = MultinomialNB()
    model8 = GaussianNB()
    model9 = BernoulliNB()
    model10 = svm.SVC(C=1.0, kernel='rbf', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=True,
                      tol=0.001, cache_size=1000, class_weight=None, verbose=False, max_iter=200,
                      decision_function_shape='ovr', random_state=None)
    model11 = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=True,
                      tol=0.001, cache_size=1000, class_weight=None, verbose=False, max_iter=100,
                      decision_function_shape='ovr', random_state=None)
    model12 = svm.SVC(C=1.0, kernel='poly', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=True,
                      tol=0.001, cache_size=1000, class_weight=None, verbose=False, max_iter=25,
                      decision_function_shape='ovr', random_state=None)
    model13 = svm.SVC(C=1.0, kernel='sigmoid', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=True,
                      tol=0.001, cache_size=1000, class_weight=None, verbose=False, max_iter=100,
                      decision_function_shape='ovr', random_state=None)
    models = [model1, model2, model3, model4, model5, model6, model7, model8, model9, model10, model11, model12,
              model13]

    if model_process == 0:
        process_id = int(input("Test or development? (0/1)"))
        if process_id == 0:
            print("x-val train_set")
            score0 = cross_validate(model1, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score1 = cross_validate(model2, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score2 = cross_validate(model3, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score3 = cross_validate(model4, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score4 = cross_validate(model5, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score5 = cross_validate(model6, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score6 = cross_validate(model7, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score7 = cross_validate(model8, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score8 = cross_validate(model9, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score9 = cross_validate(model10, train_features, train_labels, scoring=scoring, cv=5,
                                    return_train_score=False)
            score10 = cross_validate(model11, train_features, train_labels, scoring=scoring, cv=5,
                                     return_train_score=False)
            score11 = cross_validate(model12, train_features, train_labels, scoring=scoring, cv=5,
                                     return_train_score=False)
            scores = [score0, score1, score2, score3, score4, score5, score6, score7, score8, score9, score10, score11]
            print('Train set model output...\n')
            for i, d in enumerate(scores):
                print(algorithm_names[i])
                for c, e in enumerate(scoring_parse_labels):
                    item = d.pop(e)
                    item = item.astype(np.float)
                    if scoring_parse_labels[c] == 'fit_time' or scoring_parse_labels[c] == 'score_time':
                        print(scoring_parse_labels[c], ':', '%0.6f' % (np.mean(item)))
                    else:
                        print(scoring_parse_labels[c], ':', '%0.0f' % (float(np.mean(item) * 100)) + '%')
                        if scoring_parse_labels[c] == 'test_f1':
                            print('\n')
        elif process_id == 1:
            print("ROC curve development")
            cv = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)
            X, y = train_dev_features, train_dev_labels
            k = 0
            d = int(input('model record output (0/1): '))
            scores = []
            for model in models:
                i = 0
                if d == 0:
                    try:
                        tprs = []
                        aucs = []
                        mean_fpr = np.linspace(0, 1, 100)
                        for train, test in cv.split(X, y):
                            probas_ = model.fit(X[train], y[train]).predict_proba(X[test])
                            # Compute ROC curve and area the curve
                            fpr, tpr, thresholds = roc_curve(y[test], probas_[:, 1])
                            tprs.append(interp1d(mean_fpr, fpr, tpr))
                            tprs[-1][0] = 0.0
                            roc_auc = auc(fpr, tpr)
                            aucs.append(roc_auc)
                            plt.plot(fpr, tpr, lw=1, alpha=0.5, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))
                            i += 1
                        mean_tpr = np.mean(tprs, axis=0)
                        mean_tpr[-1] = 1.0
                        mean_auc = auc(mean_fpr, mean_tpr)
                        std_auc = np.std(aucs)
                        plt.plot(mean_fpr, mean_tpr, color='b',
                                 label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
                                 lw=2, alpha=.8)
                        std_tpr = np.std(tprs, axis=0)
                        tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
                        tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
                        plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                                         label=r'$\pm$ 1 std. dev.')
                        plt.xlim([-0.05, 1.05])
                        plt.ylim([-0.05, 1.05])
                        plt.xlabel('False Positive Rate')
                        plt.ylabel('True Positive Rate')
                        plt.title('Development - ROC: ' + algorithm_names[k])
                        plt.legend(loc="lower right")
                        plt.savefig(
                            "../results/plots/development/Development-ROC_%s_%0i_features_%0i_test.png" % (
                                algorithm_names[k], feature_size, len(test_set)),
                            dpi=100,
                            facecolor='w', edgecolor='b', linewidth=1, orientation='portrait', papertype=None,
                            format="png", transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None)
                        print("Created %s ROC figure" % (algorithm_names[k]))
                        plt.close()
                        k += 1
                    except (AttributeError, OverflowError) as detail:
                        print(algorithm_names[k] + " Failed due to ", detail)
                        k += 1
                        pass
                elif d == 1:
                    scores.append(cross_validate(model, X, y, cv=cv, scoring=scoring, return_train_score=False))

            for i, d in enumerate(scores):
                print(algorithm_names[i])
                for c, e in enumerate(scoring_parse_labels):
                    item = d.pop(e)
                    item = item.astype(np.float)
                    if scoring_parse_labels[c] == 'fit_time' or scoring_parse_labels[c] == 'score_time':
                        print(scoring_parse_labels[c], ':', '%0.6f' % (np.mean(item)))
                    else:
                        print(scoring_parse_labels[c], ':', '%0.0f' % (float(np.mean(item) * 100)) + '%')
                        if scoring_parse_labels[c] == 'test_f1':
                            print('\n')

    elif model_process == 1:
        print("ROC Curve output")
        cv = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)
        X, y = test_features, test_labels
        k = 0
        for model in models:
            i = 0
            try:
                tprs = []
                aucs = []
                mean_fpr = np.linspace(0, 1, 100)
                for train, test in cv.split(X, y):
                    probas_ = model.fit(X[train], y[train]).predict_proba(X[test])
                    # Compute ROC curve and area the curve
                    fpr, tpr, thresholds = roc_curve(y[test], probas_[:, 1])
                    tprs.append(interp1d(mean_fpr, fpr, tpr))
                    tprs[-1][0] = 0.0
                    roc_auc = auc(fpr, tpr)
                    aucs.append(roc_auc)
                    plt.plot(fpr, tpr, lw=1, alpha=0.5, label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))
                    i += 1
                mean_tpr = np.mean(tprs, axis=0)
                mean_tpr[-1] = 1.0
                mean_auc = auc(mean_fpr, mean_tpr)
                std_auc = np.std(aucs)
                plt.plot(mean_fpr, mean_tpr, color='b',
                         label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
                         lw=2, alpha=.8)
                std_tpr = np.std(tprs, axis=0)
                tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
                tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
                plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2, label=r'$\pm$ 1 std. dev.')
                plt.xlim([-0.05, 1.05])
                plt.ylim([-0.05, 1.05])
                plt.xlabel('False Positive Rate')
                plt.ylabel('True Positive Rate')
                plt.title('ROC: ' + algorithm_names[k])
                plt.legend(loc="lower right")
                plt.savefig(
                    "../results/plots/test/ROC_%s_%0i_features_%0i_test.png" % (
                        algorithm_names[k], feature_size, len(test_set)),
                    dpi=100,
                    facecolor='w', edgecolor='b', linewidth=1, orientation='portrait', papertype=None,
                    format="png", transparent=False, bbox_inches=None, pad_inches=0.1, frameon=None)
                print("Created %s ROC figure" % (algorithm_names[k]))
                plt.close()
                k += 1
            except (AttributeError, OverflowError) as detail:
                print(algorithm_names[k] + " Failed due to ", detail)
                k += 1
                pass


def calculate(ham, spam):
    main_proportion = 0.8
    ham_size = int(len(ham) * main_proportion)
    ham_train, ham_test = ham[:ham_size], ham[ham_size:]
    spam_size = int(len(spam) * main_proportion)
    spam_train, spam_test = spam[:spam_size], spam[spam_size:]
    ham_train_size, spam_train_size = int(len(ham_train) * main_proportion), int(len(spam_train) * main_proportion)
    ham_train, ham_train_dev = ham_train[:ham_train_size], ham_train[ham_train_size:]
    spam_train, spam_train_dev = spam_train[:spam_train_size], spam_train[spam_train_size:]
    train_set, train_dev_set, test_set = ham_train + spam_train, ham_train_dev + spam_train_dev, ham_test + spam_test
    train_labels = np.zeros(len(train_set))
    train_labels[(int((len(train_set)) - len(spam_train))):len(train_set)] = 1
    train_dev_labels = np.zeros(len(train_dev_set))
    train_dev_labels[(int((len(train_dev_set)) - len(spam_train_dev))):len(train_dev_set)] = 1
    test_labels = np.zeros(len(test_set))
    test_labels[(int((len(test_set)) - len(spam_test))):len(test_set)] = 1
    print("Train set:\n", "Ham: ", str(len(ham_train)), "\n", "Spam: ", str(len(spam_train)),
          "\nTrain_Dev:\n Ham:", str(len(ham_train_dev)), "\n Spam:", str(len(spam_train_dev)),
          "\nTest set:\n", "Ham: ", str(len(ham_test)), "\n", "Spam: ", str(len(spam_test)))
    return train_set, test_set, train_labels, test_labels, train_dev_set, train_dev_labels


def load_(file, label):
    with open(file, 'r') as fp:
        values = []
        doc_id = 0
        size_file = fp.read().split(";")
        for item in size_file:
            process_status(doc_id, size_file, "loading " + label + " file...")
            values.append(item.split(", "))
            doc_id += 1
        return values


def process_status(id, data, label):
    if id + 1 < int(len(data)):
        end_atp = "\r"
    elif id + 1 <= int(len(data)):
        end_atp = "\n"
    return print(label, '%0.0i out of %0.0i: %0.0i' %
                 (id + 1, len(data), int((id + 1) * (100 / len(data)))), '%', end='\r', flush=False)


def test_1(train, test):  # Multi-layer perceptron neural network test.
    nu_val = [10, 25, 50, 75, 100, 150, 200]
    h_layers = [1, 2, 3, 4, 5]
    iter_val = [10, 25, 50, 100, 200]
    scores = []
    scoring = ['precision_macro', 'recall_macro', 'f1']
    scoring_parse_labels = ['fit_time', 'score_time', 'test_precision_macro', 'test_recall_macro', 'test_f1']
    cv = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)
    i = 0
    for a in range(len(nu_val)):
        for b in range(len(h_layers)):
            if b > 0:
                if b == 1:
                    nu_layer_val = nu_val[a], nu_val[a]
                elif b == 2:
                    nu_layer_val = nu_val[a], nu_val[a], nu_val[a]
                elif b == 3:
                    nu_layer_val = nu_val[a], nu_val[a], nu_val[a], nu_val[a]
                elif b == 4:
                    nu_layer_val = nu_val[a], nu_val[a], nu_val[a], nu_val[a], nu_val[a]
            else:
                nu_layer_val = nu_val[a]
            for c in range(len(iter_val)):
                print('%0.0i out of %0.0i/ %0.0i' %
                      (i, (int(len(nu_val) * len(h_layers) * len(iter_val))),
                       int(i * (100 / (int(len(nu_val) * len(h_layers) * len(iter_val)))))) + '%',
                      end='\r', flush=True)
                model = MLPClassifier(hidden_layer_sizes=(nu_layer_val), solver='lbfgs', max_iter=iter_val[c])
                scores.append(cross_validate(model, train, test, cv=cv, scoring=scoring, return_train_score=False))
                i += 1
    with open('test_1.csv', 'w', newline='') as csvfile:
        filewriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        filewriter.writerow(scoring_parse_labels)
        for i, d in enumerate(scores):
            processed_scores = []
            for c, e in enumerate(scoring_parse_labels):
                item = d.pop(e)
                item = item.astype(np.float)
                if scoring_parse_labels[c] == 'fit_time' or scoring_parse_labels[c] == 'score_time':
                    processed_scores.append('%0.6f' % (np.mean(item)))
                else:
                    processed_scores.append('%0.2f' % (float(np.mean(item))))
            filewriter.writerow(processed_scores)


def test_2(train, test):
    scores = []
    scoring = ['precision_macro', 'recall_macro', 'f1']
    scoring_parse_labels = ['fit_time', 'score_time', 'test_precision_macro', 'test_recall_macro', 'test_f1']
    cv = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(train)
    i = 0
    kernal_val = ['linear', 'poly', 'rbf', 'sigmoid']
    iter_val = [10, 25, 50, 100, 200]
    for a in range(len(kernal_val)):
        for b in range(len(iter_val)):
            print('%0.0i out of %0.0i/ %0.0i' %
                  (i, (int(len(kernal_val) * len(iter_val))), int(i * (100 / (int(len(kernal_val) * len(iter_val))))))
                  + '%', end='\r', flush=True)
            model = svm.SVC(C=1.0, kernel=kernal_val[a], degree=3, gamma='auto', coef0=0.0, shrinking=True,
                            probability=True, tol=0.001, cache_size=10000, class_weight=None, verbose=False,
                            max_iter=iter_val[b], decision_function_shape='ovr', random_state=None)
            scores.append(cross_validate(model, scaled_data, test, cv=cv, scoring=scoring, return_train_score=False))
            i += 1
    with open('test_2.csv', 'w', newline='') as csvfile:
        filewriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        filewriter.writerow(scoring_parse_labels)
        for i, d in enumerate(scores):
            processed_scores = []
            for c, e in enumerate(scoring_parse_labels):
                item = d.pop(e)
                item = item.astype(np.float)
                if scoring_parse_labels[c] == 'fit_time' or scoring_parse_labels[c] == 'score_time':
                    processed_scores.append('%0.6f' % (np.mean(item)))
                else:
                    processed_scores.append('%0.2f' % (float(np.mean(item))))
            filewriter.writerow(processed_scores)


def test_3(train, test):  # todo Knn classifier test.
    scores = []
    scoring = ['precision_macro', 'recall_macro', 'f1']
    scoring_parse_labels = ['fit_time', 'score_time', 'test_precision_macro', 'test_recall_macro', 'test_f1']
    cv = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)
    i = 0
    algorithm_val = ['ball_tree', 'kd_tree', 'brute']
    for a in range(len(algorithm_val)):
        model = KNeighborsClassifier(algorithm=algorithm_val[a])
        scores.append(cross_validate(model, train, test, cv=cv, scoring=scoring, return_train_score=False))
        i += 1
    with open('test_3.csv', 'w', newline='') as csvfile:
        filewriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        filewriter.writerow(scoring_parse_labels)
        for i, d in enumerate(scores):
            processed_scores = []
            for c, e in enumerate(scoring_parse_labels):
                item = d.pop(e)
                item = item.astype(np.float)
                if scoring_parse_labels[c] == 'fit_time' or scoring_parse_labels[c] == 'score_time':
                    processed_scores.append('%0.6f' % (np.mean(item)))
                else:
                    processed_scores.append('%0.2f' % (float(np.mean(item))))
            filewriter.writerow(processed_scores)


def test_4(train, test):
    scores = []
    scoring = ['precision_macro', 'recall_macro', 'f1']
    scoring_parse_labels = ['fit_time', 'score_time', 'test_precision_macro', 'test_recall_macro', 'test_f1']
    cv = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)
    i = 0
    model = LogisticRegression()
    scores.append(cross_validate(model, train, test, cv=cv, scoring=scoring, return_train_score=False))
    i += 1
    with open('test_4.csv', 'w', newline='') as csvfile:
        filewriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        filewriter.writerow(scoring_parse_labels)
        for i, d in enumerate(scores):
            processed_scores = []
            for c, e in enumerate(scoring_parse_labels):
                item = d.pop(e)
                item = item.astype(np.float)
                if scoring_parse_labels[c] == 'fit_time' or scoring_parse_labels[c] == 'score_time':
                    processed_scores.append('%0.6f' % (np.mean(item)))
                else:
                    processed_scores.append('%0.2f' % (float(np.mean(item))))
            filewriter.writerow(processed_scores)


def feature_test(train, test):  # function to test and record via csv, all algorithms selected.
    scores = []
    scoring = ['precision_macro', 'recall_macro', 'f1']
    scoring_parse_labels = ['fit_time', 'score_time', 'test_precision_macro', 'test_recall_macro', 'test_f1']
    cv = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)
    model1 = KNeighborsClassifier(algorithm='brute')
    model2 = MLPClassifier(hidden_layer_sizes=75, solver='lbfgs', max_iter=25)
    model3 = MLPClassifier(hidden_layer_sizes=(150, 150), solver='lbfgs', max_iter=25)
    model4 = LogisticRegression(solver='lbfgs', max_iter=25)
    model5 = RandomForestClassifier(n_estimators=50, max_depth=None, min_samples_split=2, random_state=0)
    model6 = XGBClassifier()
    model7 = MultinomialNB()
    model8 = GaussianNB()
    model9 = BernoulliNB()
    model10 = svm.SVC(C=1.0, kernel='rbf', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=True,
                      tol=0.001, cache_size=1000, class_weight=None, verbose=False, max_iter=200,
                      decision_function_shape='ovr', random_state=None)
    model11 = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=True,
                      tol=0.001, cache_size=1000, class_weight=None, verbose=False, max_iter=100,
                      decision_function_shape='ovr', random_state=None)
    model12 = svm.SVC(C=1.0, kernel='poly', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=True,
                      tol=0.001, cache_size=1000, class_weight=None, verbose=False, max_iter=25,
                      decision_function_shape='ovr', random_state=None)
    model13 = svm.SVC(C=1.0, kernel='sigmoid', degree=3, gamma='auto', coef0=0.0, shrinking=True, probability=True,
                      tol=0.001, cache_size=1000, class_weight=None, verbose=False, max_iter=100,
                      decision_function_shape='ovr', random_state=None)
    models = [model1, model2, model3, model4, model5, model6, model7, model8, model9, model10, model11, model12,
              model13]
    for a in range(len(models)):
        scores.append(cross_validate(models[a], train, test, cv=cv, scoring=scoring, return_train_score=False))
    with open('feature_test_1.csv', 'w', newline='') as csvfile:
        filewriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        filewriter.writerow(scoring_parse_labels)
        for i, d in enumerate(scores):
            processed_scores = []
            for c, e in enumerate(scoring_parse_labels):
                item = d.pop(e)
                item = item.astype(np.float)
                if scoring_parse_labels[c] == 'fit_time' or scoring_parse_labels[c] == 'score_time':
                    processed_scores.append('%0.6f' % (np.mean(item)))
                else:
                    processed_scores.append('%0.2f' % (float(np.mean(item))))

            filewriter.writerow(processed_scores)


def svm_test(X, y):  # function test for SVM models specified.
    scaler = MinMaxScaler(feature_range=(0, 1), copy=True)
    X_scaled = scaler.fit_transform(X, y=y)
    scores = []
    scoring = ['precision_macro', 'recall_macro', 'f1']
    scoring_parse_labels = ['fit_time', 'score_time', 'test_precision_macro', 'test_recall_macro', 'test_f1']
    cv = StratifiedKFold(n_splits=5, shuffle=False, random_state=None)
    model1 = svm.LinearSVC()
    model2 = svm.NuSVC()
    models = [model1, model2]
    kernel_list = ['linear', 'rbf', 'poly', 'sigmoid']
    max_iter = [10, 25, 50, 75, 100, 150, 200]
    for a in range(len(models)):
        if a == 0:
            for c in range(len(max_iter)):
                print('linear:')
                model = svm.LinearSVC(max_iter=max_iter[c])
                scores.append(cross_validate(model, X, y, cv=cv, scoring=scoring, return_train_score=False))
        elif a == 1:
            pass
    with open('svm_svc_test.csv', 'w', newline='') as csvfile:  # function to save output to csv file.
        filewriter = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)
        filewriter.writerow(scoring_parse_labels)
        for i, d in enumerate(scores):
            processed_scores = []
            for c, e in enumerate(scoring_parse_labels):
                item = d.pop(e)
                item = item.astype(np.float)
                if scoring_parse_labels[c] == 'fit_time' or scoring_parse_labels[c] == 'score_time':
                    processed_scores.append('%0.6f' % (np.mean(item)))
                else:
                    processed_scores.append('%0.2f' % (float(np.mean(item))))

            filewriter.writerow(processed_scores)

# %%
if __name__ == "__main__":
    feature_size = int(input("Type amount of features to use: "))
    model_process = str(input("Extract features or Test models? [Extract features = y, Test models = n")) == 'y'
    time_initiate = time()
    a_files = ["../data/processed_ham.txt", "../data/processed_spam.txt"]
    a_exist = [f for f in a_files if os.path.isfile(f)]
    usePreprocessedDatasets = False
    if a_exist:
        usePreprocessedDatasets = str(input("Preprocessed datasets for ham and spam found, would you like to use them? [y/n]")) == 'y'

    if usePreprocessedDatasets:
        ham_collection = load_(a_files[0], "ham")
        spam_collection = load_(a_files[1], "spam")
    else:
        ham_collection, spam_collection = enron_selector()
    dictionary = dictionary_build((ham_collection + spam_collection))
    dictionary = dictionary.most_common(feature_size)
    print(dictionary, "\n")
    train_set, test_set, train_labels, test_labels, train_dev_set, train_dev_labels = calculate(ham_collection,
                                                                                                spam_collection)
    if model_process:
        train_features = extract_features(train_set, "train")
        train_dev_features = extract_features(train_dev_set, "train_dev")
        test_features, test_labels = 0, 0
    else:
        test_features = extract_features(test_set, "test")
        train_features, train_labels = 0, 0
        train_dev_features, train_dev_labels = 0, 0
    models(
        train_features,
        train_dev_features,
        test_features,
        train_labels,
        train_dev_labels,
        test_labels,
        model_process,
        feature_size,
        test_set
    )
    test_1(train_dev_features, train_dev_labels)
    test_2(train_dev_features, train_dev_labels)
    test_3(train_dev_features, train_dev_labels)
    test_4(train_dev_features, train_dev_labels)
    feature_test(train_dev_features, train_dev_labels)
    svm_test(train_dev_features, train_dev_labels)
    print("Script complete: %0.1f" % (time() - time_initiate))
# Out:
# Type amount of features to use: 50
# Extract features or Test models? [Extract features = y, Test models = ny
# Preprocessed datasets for ham and spam found, would you like to use them? [y/n]n
# Loading spam... 1 out of 17168: 0 %
# Loading spam... 2 out of 17168: 0 %
# Loading spam... 3 out of 17168: 0 %
# Loading spam... 4 out of 17168: 0 %
# Loading spam... 5 out of 17168: 0 %
# Loading spam... 6 out of 17168: 0 %
# Loading spam... 7 out of 17168: 0 %
# Loading spam... 8 out of 17168: 0 %
# Loading spam... 9 out of 17168: 0 %
# Loading spam... 10 out of 17168: 0 %
# Loading spam... 11 out of 17168: 0 %
# Loading spam... 12 out of 17168: 0 %
# Loading spam... 13 out of 17168: 0 %
# Loading spam... 14 out of 17168: 0 %
# Loading spam... 15 out of 17168: 0 %
# Loading spam... 16 out of 17168: 0 %
# Loading spam... 17 out of 17168: 0 %
# Loading spam... 18 out of 17168: 0 %
# Loading spam... 19 out of 17168: 0 %
# Loading spam... 20 out of 17168: 0 %
# Loading spam... 21 out of 17168: 0 %
# Loading spam... 22 out of 17168: 0 %
# Loading spam... 23 out of 17168: 0 %
# Loading spam... 24 out of 17168: 0 %
# Loading spam... 25 out of 17168: 0 %
# Loading spam... 26 out of 17168: 0 %
# Loading spam... 27 out of 17168: 0 %
# Loading spam... 28 out of 17168: 0 %
# Loading spam... 29 out of 17168: 0 %
# Loading spam... 30 out of 17168: 0 %
# Loading spam... 31 out of 17168: 0 %
# Loading spam... 32 out of 17168: 0 %
# Loading spam... 33 out of 17168: 0 %
# Loading spam... 34 out of 17168: 0 %
# Loading spam... 35 out of 17168: 0 %
# Loading spam... 36 out of 17168: 0 %
# Loading spam... 37 out of 17168: 0 %
# Loading spam... 38 out of 17168: 0 %
# Loading spam... 39 out of 17168: 0 %
# Loading spam... 40 out of 17168: 0 %
# Loading spam... 41 out of 17168: 0 %
# Loading spam... 42 out of 17168: 0 %
# Loading spam... 43 out of 17168: 0 %
# Loading spam... 44 out of 17168: 0 %
# Loading spam... 45 out of 17168: 0 %
# Loading spam... 46 out of 17168: 0 %
# Loading spam... 47 out of 17168: 0 %
# Loading spam... 48 out of 17168: 0 %
# Loading spam... 49 out of 17168: 0 %
# Loading spam... 50 out of 17168: 0 %
# Loading spam... 51 out of 17168: 0 %
# Loading spam... 52 out of 17168: 0 %
# Loading spam... 53 out of 17168: 0 %
# Loading spam... 54 out of 17168: 0 %
# Loading spam... 55 out of 17168: 0 %
# Loading spam... 56 out of 17168: 0 %
# Loading spam... 57 out of 17168: 0 %
# Loading spam... 58 out of 17168: 0 %
# Loading spam... 59 out of 17168: 0 %
# Loading spam... 60 out of 17168: 0 %
# Loading spam... 61 out of 17168: 0 %
# Loading spam... 62 out of 17168: 0 %
# Loading spam... 63 out of 17168: 0 %
# Loading spam... 64 out of 17168: 0 %
# Loading spam... 65 out of 17168: 0 %
# Loading spam... 66 out of 17168: 0 %
# Loading spam... 67 out of 17168: 0 %
# Loading spam... 68 out of 17168: 0 %
# Loading spam... 69 out of 17168: 0 %
# Loading spam... 70 out of 17168: 0 %
# Loading spam... 71 out of 17168: 0 %
# Loading spam... 72 out of 17168: 0 %
# Loading spam... 73 out of 17168: 0 %
# Loading spam... 74 out of 17168: 0 %
# Loading spam... 75 out of 17168: 0 %
# Loading spam... 76 out of 17168: 0 %
# Loading spam... 77 out of 17168: 0 %
# Loading spam... 78 out of 17168: 0 %
# Loading spam... 79 out of 17168: 0 %
# Loading spam... 80 out of 17168: 0 %
# Loading spam... 81 out of 17168: 0 %
# Loading spam... 82 out of 17168: 0 %
# Loading spam... 83 out of 17168: 0 %
# Loading spam... 84 out of 17168: 0 %
# Loading spam... 85 out of 17168: 0 %
# Loading spam... 86 out of 17168: 0 %
# Loading spam... 87 out of 17168: 0 %
# Loading spam... 88 out of 17168: 0 %
# Loading spam... 89 out of 17168: 0 %
# Loading spam... 90 out of 17168: 0 %
# Loading spam... 91 out of 17168: 0 %
# Loading spam... 92 out of 17168: 0 %
# Loading spam... 93 out of 17168: 0 %
# Loading spam... 94 out of 17168: 0 %
# Loading spam... 95 out of 17168: 0 %
# Loading spam... 96 out of 17168: 0 %
# Loading spam... 97 out of 17168: 0 %
# Loading spam... 98 out of 17168: 0 %
# Loading spam... 99 out of 17168: 0 %
# Loading spam... 100 out of 17168: 0 %
# Loading spam... 101 out of 17168: 0 %
# Loading spam... 102 out of 17168: 0 %
# Loading spam... 103 out of 17168: 0 %
# Loading spam... 104 out of 17168: 0 %
# Loading spam... 105 out of 17168: 0 %
# Loading spam... 106 out of 17168: 0 %
# Loading spam... 107 out of 17168: 0 %
# Loading spam... 108 out of 17168: 0 %
# Loading spam... 109 out of 17168: 0 %
# Loading spam... 110 out of 17168: 0 %
# Loading spam... 111 out of 17168: 0 %
# Loading spam... 112 out of 17168: 0 %
# Loading spam... 113 out of 17168: 0 %
# Loading spam... 114 out of 17168: 0 %
# Loading spam... 115 out of 17168: 0 %
# Loading spam... 116 out of 17168: 0 %
# Loading spam... 117 out of 17168: 0 %
# Loading spam... 118 out of 17168: 0 %
# Loading spam... 119 out of 17168: 0 %
# Loading spam... 120 out of 17168: 0 %
# Loading spam... 121 out of 17168: 0 %
# Loading spam... 122 out of 17168: 0 %
# Loading spam... 123 out of 17168: 0 %
# Loading spam... 124 out of 17168: 0 %
# Loading spam... 125 out of 17168: 0 %
# Loading spam... 126 out of 17168: 0 %
# Loading spam... 127 out of 17168: 0 %
# Loading spam... 128 out of 17168: 0 %
# Loading spam... 129 out of 17168: 0 %
# Loading spam... 130 out of 17168: 0 %
# Loading spam... 131 out of 17168: 0 %
# Loading spam... 132 out of 17168: 0 %
# Loading spam... 133 out of 17168: 0 %
# Loading spam... 134 out of 17168: 0 %
# Loading spam... 135 out of 17168: 0 %
# Loading spam... 136 out of 17168: 0 %
# Loading spam... 137 out of 17168: 0 %
# Loading spam... 138 out of 17168: 0 %
# Loading spam... 139 out of 17168: 0 %
# Loading spam... 140 out of 17168: 0 %
# Loading spam... 141 out of 17168: 0 %
# Loading spam... 142 out of 17168: 0 %
# Loading spam... 143 out of 17168: 0 %
# Loading spam... 144 out of 17168: 0 %
# Loading spam... 145 out of 17168: 0 %
# Loading spam... 146 out of 17168: 0 %
# Loading spam... 147 out of 17168: 0 %
# Loading spam... 148 out of 17168: 0 %
# Loading spam... 149 out of 17168: 0 %
# Loading spam... 150 out of 17168: 0 %
# Loading spam... 151 out of 17168: 0 %
# Loading spam... 152 out of 17168: 0 %
# Loading spam... 153 out of 17168: 0 %
# Loading spam... 154 out of 17168: 0 %
# Loading spam... 155 out of 17168: 0 %
# Loading spam... 156 out of 17168: 0 %
# Loading spam... 157 out of 17168: 0 %
# Loading spam... 158 out of 17168: 0 %
# Loading spam... 159 out of 17168: 0 %
# Loading spam... 160 out of 17168: 0 %
# Loading spam... 161 out of 17168: 0 %
# Loading spam... 162 out of 17168: 0 %
# Loading spam... 163 out of 17168: 0 %
# Loading spam... 164 out of 17168: 0 %
# Loading spam... 165 out of 17168: 0 %
# Loading spam... 166 out of 17168: 0 %
# Loading spam... 167 out of 17168: 0 %
# Loading spam... 168 out of 17168: 0 %
# Loading spam... 169 out of 17168: 0 %
# Loading spam... 170 out of 17168: 0 %
# Loading spam... 171 out of 17168: 0 %
# Loading spam... 172 out of 17168: 1 %
# Loading spam... 173 out of 17168: 1 %
# Loading spam... 174 out of 17168: 1 %
# Loading spam... 175 out of 17168: 1 %
# Loading spam... 176 out of 17168: 1 %
# Loading spam... 177 out of 17168: 1 %
# Loading spam... 178 out of 17168: 1 %
# Loading spam... 179 out of 17168: 1 %
# Loading spam... 180 out of 17168: 1 %
# Loading spam... 181 out of 17168: 1 %
# Loading spam... 182 out of 17168: 1 %
# Loading spam... 183 out of 17168: 1 %
# Loading spam... 184 out of 17168: 1 %
# Loading spam... 185 out of 17168: 1 %
# Loading spam... 186 out of 17168: 1 %
# Loading spam... 187 out of 17168: 1 %
# Loading spam... 188 out of 17168: 1 %
# Loading spam... 189 out of 17168: 1 %
# Loading spam... 190 out of 17168: 1 %
# Loading spam... 191 out of 17168: 1 %
# Loading spam... 192 out of 17168: 1 %
# Loading spam... 193 out of 17168: 1 %
# Loading spam... 194 out of 17168: 1 %
# Loading spam... 195 out of 17168: 1 %
# Loading spam... 196 out of 17168: 1 %
# Loading spam... 197 out of 17168: 1 %
# Loading spam... 198 out of 17168: 1 %
# Loading spam... 199 out of 17168: 1 %
# Loading spam... 200 out of 17168: 1 %
# Loading spam... 201 out of 17168: 1 %
# Loading spam... 202 out of 17168: 1 %
# Loading spam... 203 out of 17168: 1 %
# Loading spam... 204 out of 17168: 1 %
# Loading spam... 205 out of 17168: 1 %
# Loading spam... 206 out of 17168: 1 %
# Loading spam... 207 out of 17168: 1 %
# Loading spam... 208 out of 17168: 1 %
# Loading spam... 209 out of 17168: 1 %
# Loading spam... 210 out of 17168: 1 %
# Loading spam... 211 out of 17168: 1 %
# Loading spam... 212 out of 17168: 1 %
# Loading spam... 213 out of 17168: 1 %
# Loading spam... 214 out of 17168: 1 %
# Loading spam... 215 out of 17168: 1 %
# Loading spam... 216 out of 17168: 1 %
# Loading spam... 217 out of 17168: 1 %
# Loading spam... 218 out of 17168: 1 %
# Loading spam... 219 out of 17168: 1 %
# Loading spam... 220 out of 17168: 1 %
# Loading spam... 221 out of 17168: 1 %
# Loading spam... 222 out of 17168: 1 %
# Loading spam... 223 out of 17168: 1 %
# Loading spam... 224 out of 17168: 1 %
# Loading spam... 225 out of 17168: 1 %
# Loading spam... 226 out of 17168: 1 %
# Loading spam... 227 out of 17168: 1 %
# Loading spam... 228 out of 17168: 1 %
# Loading spam... 229 out of 17168: 1 %
# Loading spam... 230 out of 17168: 1 %
# Loading spam... 231 out of 17168: 1 %
# Loading spam... 232 out of 17168: 1 %
# Loading spam... 233 out of 17168: 1 %
# Loading spam... 234 out of 17168: 1 %
# Loading spam... 235 out of 17168: 1 %
# Loading spam... 236 out of 17168: 1 %
# Loading spam... 237 out of 17168: 1 %
# Loading spam... 238 out of 17168: 1 %
# Loading spam... 239 out of 17168: 1 %
# Loading spam... 240 out of 17168: 1 %
# Loading spam... 241 out of 17168: 1 %
# Loading spam... 242 out of 17168: 1 %
# Loading spam... 243 out of 17168: 1 %
# Loading spam... 244 out of 17168: 1 %
# Loading spam... 245 out of 17168: 1 %
# Loading spam... 246 out of 17168: 1 %
# Loading spam... 247 out of 17168: 1 %
# Loading spam... 248 out of 17168: 1 %
# Loading spam... 249 out of 17168: 1 %
# Loading spam... 250 out of 17168: 1 %
# Loading spam... 251 out of 17168: 1 %
# Loading spam... 252 out of 17168: 1 %
# Loading spam... 253 out of 17168: 1 %
# Loading spam... 254 out of 17168: 1 %
# Loading spam... 255 out of 17168: 1 %
# Loading spam... 256 out of 17168: 1 %
# Loading spam... 257 out of 17168: 1 %
# Loading spam... 258 out of 17168: 1 %
# Loading spam... 259 out of 17168: 1 %
# Loading spam... 260 out of 17168: 1 %
# Loading spam... 261 out of 17168: 1 %
# Loading spam... 262 out of 17168: 1 %
# Loading spam... 263 out of 17168: 1 %
# Loading spam... 264 out of 17168: 1 %
# Loading spam... 265 out of 17168: 1 %
# Loading spam... 266 out of 17168: 1 %
# Loading spam... 267 out of 17168: 1 %
# Loading spam... 268 out of 17168: 1 %
# Loading spam... 269 out of 17168: 1 %
# Loading spam... 270 out of 17168: 1 %
# Loading spam... 271 out of 17168: 1 %
# Loading spam... 272 out of 17168: 1 %
# Loading spam... 273 out of 17168: 1 %
# Loading spam... 274 out of 17168: 1 %
# Loading spam... 275 out of 17168: 1 %
# Loading spam... 276 out of 17168: 1 %
# Loading spam... 277 out of 17168: 1 %
# Loading spam... 278 out of 17168: 1 %
# Loading spam... 279 out of 17168: 1 %
# Loading spam... 280 out of 17168: 1 %
# Loading spam... 281 out of 17168: 1 %
# Loading spam... 282 out of 17168: 1 %
# Loading spam... 283 out of 17168: 1 %
# Loading spam... 284 out of 17168: 1 %
# Loading spam... 285 out of 17168: 1 %
# Loading spam... 286 out of 17168: 1 %
# Loading spam... 287 out of 17168: 1 %
# Loading spam... 288 out of 17168: 1 %
# Loading spam... 289 out of 17168: 1 %
# Loading spam... 290 out of 17168: 1 %
# Loading spam... 291 out of 17168: 1 %
# Loading spam... 292 out of 17168: 1 %
# Loading spam... 293 out of 17168: 1 %
# Loading spam... 294 out of 17168: 1 %
# Loading spam... 295 out of 17168: 1 %
# Loading spam... 296 out of 17168: 1 %
# Loading spam... 297 out of 17168: 1 %
# Loading spam... 298 out of 17168: 1 %
# Loading spam... 299 out of 17168: 1 %
# Loading spam... 300 out of 17168: 1 %
# Loading spam... 301 out of 17168: 1 %
# Loading spam... 302 out of 17168: 1 %
# Loading spam... 303 out of 17168: 1 %
# Loading spam... 304 out of 17168: 1 %
# Loading spam... 305 out of 17168: 1 %
# Loading spam... 306 out of 17168: 1 %
# Loading spam... 307 out of 17168: 1 %
# Loading spam... 308 out of 17168: 1 %
# Loading spam... 309 out of 17168: 1 %
# Loading spam... 310 out of 17168: 1 %
# Loading spam... 311 out of 17168: 1 %
# Loading spam... 312 out of 17168: 1 %
# Loading spam... 313 out of 17168: 1 %
# Loading spam... 314 out of 17168: 1 %
# Loading spam... 315 out of 17168: 1 %
# Loading spam... 316 out of 17168: 1 %
# Loading spam... 317 out of 17168: 1 %
# Loading spam... 318 out of 17168: 1 %
# Loading spam... 319 out of 17168: 1 %
# Loading spam... 320 out of 17168: 1 %
# Loading spam... 321 out of 17168: 1 %
# Loading spam... 322 out of 17168: 1 %
# Loading spam... 323 out of 17168: 1 %
# Loading spam... 324 out of 17168: 1 %
# Loading spam... 325 out of 17168: 1 %
# Loading spam... 326 out of 17168: 1 %
# Loading spam... 327 out of 17168: 1 %
# Loading spam... 328 out of 17168: 1 %
# Loading spam... 329 out of 17168: 1 %
# Loading spam... 330 out of 17168: 1 %
# Loading spam... 331 out of 17168: 1 %
# Loading spam... 332 out of 17168: 1 %
# Loading spam... 333 out of 17168: 1 %
# Loading spam... 334 out of 17168: 1 %
# Loading spam... 335 out of 17168: 1 %
# Loading spam... 336 out of 17168: 1 %
# Loading spam... 337 out of 17168: 1 %
# Loading spam... 338 out of 17168: 1 %
# Loading spam... 339 out of 17168: 1 %
# Loading spam... 340 out of 17168: 1 %
# Loading spam... 341 out of 17168: 1 %
# Loading spam... 342 out of 17168: 1 %
# Loading spam... 343 out of 17168: 1 %
# Loading spam... 344 out of 17168: 2 %
# Loading spam... 345 out of 17168: 2 %
# Loading spam... 346 out of 17168: 2 %
# Loading spam... 347 out of 17168: 2 %
# Loading spam... 348 out of 17168: 2 %
# Loading spam... 349 out of 17168: 2 %
# Loading spam... 350 out of 17168: 2 %
# Loading spam... 351 out of 17168: 2 %
# Loading spam... 352 out of 17168: 2 %
# Loading spam... 353 out of 17168: 2 %
# Loading spam... 354 out of 17168: 2 %
# Loading spam... 355 out of 17168: 2 %
# Loading spam... 356 out of 17168: 2 %
# Loading spam... 357 out of 17168: 2 %
# Loading spam... 358 out of 17168: 2 %
# Loading spam... 359 out of 17168: 2 %
# Loading spam... 360 out of 17168: 2 %
# Loading spam... 361 out of 17168: 2 %
# Loading spam... 362 out of 17168: 2 %
# Loading spam... 363 out of 17168: 2 %
# Loading spam... 364 out of 17168: 2 %
# Loading spam... 365 out of 17168: 2 %
# Loading spam... 366 out of 17168: 2 %
# Loading spam... 367 out of 17168: 2 %
# Loading spam... 368 out of 17168: 2 %
# Loading spam... 369 out of 17168: 2 %
# Loading spam... 370 out of 17168: 2 %
# Loading spam... 371 out of 17168: 2 %
# Loading spam... 372 out of 17168: 2 %
# Loading spam... 373 out of 17168: 2 %
# Loading spam... 374 out of 17168: 2 %
# Loading spam... 375 out of 17168: 2 %
# Loading spam... 376 out of 17168: 2 %
# Loading spam... 377 out of 17168: 2 %
# Loading spam... 378 out of 17168: 2 %
# Loading spam... 379 out of 17168: 2 %
# Loading spam... 380 out of 17168: 2 %
# Loading spam... 381 out of 17168: 2 %
# Loading spam... 382 out of 17168: 2 %
# Loading spam... 383 out of 17168: 2 %
# Loading spam... 384 out of 17168: 2 %
# Loading spam... 385 out of 17168: 2 %
# Loading spam... 386 out of 17168: 2 %
# Loading spam... 387 out of 17168: 2 %
# Loading spam... 388 out of 17168: 2 %
# Loading spam... 389 out of 17168: 2 %
# Loading spam... 390 out of 17168: 2 %
# Loading spam... 391 out of 17168: 2 %
# Loading spam... 392 out of 17168: 2 %
# Loading spam... 393 out of 17168: 2 %
# Loading spam... 394 out of 17168: 2 %
# Loading spam... 395 out of 17168: 2 %
# Loading spam... 396 out of 17168: 2 %
# Loading spam... 397 out of 17168: 2 %
# Loading spam... 398 out of 17168: 2 %
# Loading spam... 399 out of 17168: 2 %
# Loading spam... 400 out of 17168: 2 %
# Loading spam... 401 out of 17168: 2 %
# Loading spam... 402 out of 17168: 2 %
# Loading spam... 403 out of 17168: 2 %
# Loading spam... 404 out of 17168: 2 %
# Loading spam... 405 out of 17168: 2 %
# Loading spam... 406 out of 17168: 2 %
# Loading spam... 407 out of 17168: 2 %
# Loading spam... 408 out of 17168: 2 %
# Loading spam... 409 out of 17168: 2 %
# Loading spam... 410 out of 17168: 2 %
# Loading spam... 411 out of 17168: 2 %
# Loading spam... 412 out of 17168: 2 %
# Loading spam... 413 out of 17168: 2 %
# Loading spam... 414 out of 17168: 2 %
# Loading spam... 415 out of 17168: 2 %
# Loading spam... 416 out of 17168: 2 %
# Loading spam... 417 out of 17168: 2 %
# Loading spam... 418 out of 17168: 2 %
# Loading spam... 419 out of 17168: 2 %
# Loading spam... 420 out of 17168: 2 %
# Loading spam... 421 out of 17168: 2 %
# Loading spam... 422 out of 17168: 2 %
# Loading spam... 423 out of 17168: 2 %
# Loading spam... 424 out of 17168: 2 %
# Loading spam... 425 out of 17168: 2 %
# Loading spam... 426 out of 17168: 2 %
# Loading spam... 427 out of 17168: 2 %
# Loading spam... 428 out of 17168: 2 %
# Loading spam... 429 out of 17168: 2 %
# Loading spam... 430 out of 17168: 2 %
# Loading spam... 431 out of 17168: 2 %
# Loading spam... 432 out of 17168: 2 %
# Loading spam... 433 out of 17168: 2 %
# Loading spam... 434 out of 17168: 2 %
# Loading spam... 435 out of 17168: 2 %
# Loading spam... 436 out of 17168: 2 %
# Loading spam... 437 out of 17168: 2 %
# Loading spam... 438 out of 17168: 2 %
# Loading spam... 439 out of 17168: 2 %
# Loading spam... 440 out of 17168: 2 %
# Loading spam... 441 out of 17168: 2 %
# Loading spam... 442 out of 17168: 2 %
# Loading spam... 443 out of 17168: 2 %
# Loading spam... 444 out of 17168: 2 %
# Loading spam... 445 out of 17168: 2 %
# Loading spam... 446 out of 17168: 2 %
# Loading spam... 447 out of 17168: 2 %
# Loading spam... 448 out of 17168: 2 %
# Loading spam... 449 out of 17168: 2 %
# Loading spam... 450 out of 17168: 2 %
# Loading spam... 451 out of 17168: 2 %
# Loading spam... 452 out of 17168: 2 %
# Loading spam... 453 out of 17168: 2 %
# Loading spam... 454 out of 17168: 2 %
# Loading spam... 455 out of 17168: 2 %
# Loading spam... 456 out of 17168: 2 %
# Loading spam... 457 out of 17168: 2 %
# Loading spam... 458 out of 17168: 2 %
# Loading spam... 459 out of 17168: 2 %
# Loading spam... 460 out of 17168: 2 %
# Loading spam... 461 out of 17168: 2 %
# Loading spam... 462 out of 17168: 2 %
# Loading spam... 463 out of 17168: 2 %
# Loading spam... 464 out of 17168: 2 %
# Loading spam... 465 out of 17168: 2 %
# Loading spam... 466 out of 17168: 2 %
# Loading spam... 467 out of 17168: 2 %
# Loading spam... 468 out of 17168: 2 %
# Loading spam... 469 out of 17168: 2 %
# Loading spam... 470 out of 17168: 2 %
# Loading spam... 471 out of 17168: 2 %
# Loading spam... 472 out of 17168: 2 %
# Loading spam... 473 out of 17168: 2 %
# Loading spam... 474 out of 17168: 2 %
# Loading spam... 475 out of 17168: 2 %
# Loading spam... 476 out of 17168: 2 %
# Loading spam... 477 out of 17168: 2 %
# Loading spam... 478 out of 17168: 2 %
# Loading spam... 479 out of 17168: 2 %
# Loading spam... 480 out of 17168: 2 %
# Loading spam... 481 out of 17168: 2 %
# Loading spam... 482 out of 17168: 2 %
# Loading spam... 483 out of 17168: 2 %
# Loading spam... 484 out of 17168: 2 %
# Loading spam... 485 out of 17168: 2 %
# Loading spam... 486 out of 17168: 2 %
# Loading spam... 487 out of 17168: 2 %
# Loading spam... 488 out of 17168: 2 %
# Loading spam... 489 out of 17168: 2 %
# Loading spam... 490 out of 17168: 2 %
# Loading spam... 491 out of 17168: 2 %
# Loading spam... 492 out of 17168: 2 %
# Loading spam... 493 out of 17168: 2 %
# Loading spam... 494 out of 17168: 2 %
# Loading spam... 495 out of 17168: 2 %
# Loading spam... 496 out of 17168: 2 %
# Loading spam... 497 out of 17168: 2 %
# Loading spam... 498 out of 17168: 2 %
# Loading spam... 499 out of 17168: 2 %
# Loading spam... 500 out of 17168: 2 %
# Loading spam... 501 out of 17168: 2 %
# Loading spam... 502 out of 17168: 2 %
# Loading spam... 503 out of 17168: 2 %
# Loading spam... 504 out of 17168: 2 %
# Loading spam... 505 out of 17168: 2 %
# Loading spam... 506 out of 17168: 2 %
# Loading spam... 507 out of 17168: 2 %
# Loading spam... 508 out of 17168: 2 %
# Loading spam... 509 out of 17168: 2 %
# Loading spam... 510 out of 17168: 2 %
# Loading spam... 511 out of 17168: 2 %
# Loading spam... 512 out of 17168: 2 %
# Loading spam... 513 out of 17168: 2 %
# Loading spam... 514 out of 17168: 2 %
# Loading spam... 515 out of 17168: 2 %
# Loading spam... 516 out of 17168: 3 %
# Loading spam... 517 out of 17168: 3 %
# Loading spam... 518 out of 17168: 3 %
# Loading spam... 519 out of 17168: 3 %
# Loading spam... 520 out of 17168: 3 %
# Loading spam... 521 out of 17168: 3 %
# Loading spam... 522 out of 17168: 3 %
# Loading spam... 523 out of 17168: 3 %
# Loading spam... 524 out of 17168: 3 %
# Loading spam... 525 out of 17168: 3 %
# Loading spam... 526 out of 17168: 3 %
# Loading spam... 527 out of 17168: 3 %
# Loading spam... 528 out of 17168: 3 %
# Loading spam... 529 out of 17168: 3 %
# Loading spam... 530 out of 17168: 3 %
# Loading spam... 531 out of 17168: 3 %
# Loading spam... 532 out of 17168: 3 %
# Loading spam... 533 out of 17168: 3 %
# Loading spam... 534 out of 17168: 3 %
# Loading spam... 535 out of 17168: 3 %
# Loading spam... 536 out of 17168: 3 %
# Loading spam... 537 out of 17168: 3 %
# Loading spam... 538 out of 17168: 3 %
# Loading spam... 539 out of 17168: 3 %
# Loading spam... 540 out of 17168: 3 %
# Loading spam... 541 out of 17168: 3 %
# Loading spam... 542 out of 17168: 3 %
# Loading spam... 543 out of 17168: 3 %
# Loading spam... 544 out of 17168: 3 %
# Loading spam... 545 out of 17168: 3 %
# Loading spam... 546 out of 17168: 3 %
# Loading spam... 547 out of 17168: 3 %
# Loading spam... 548 out of 17168: 3 %
# Loading spam... 549 out of 17168: 3 %
# Loading spam... 550 out of 17168: 3 %
# Loading spam... 551 out of 17168: 3 %
# Loading spam... 552 out of 17168: 3 %
# Loading spam... 553 out of 17168: 3 %
# Loading spam... 554 out of 17168: 3 %
# Loading spam... 555 out of 17168: 3 %
# Loading spam... 556 out of 17168: 3 %
# Loading spam... 557 out of 17168: 3 %
# Loading spam... 558 out of 17168: 3 %
# Loading spam... 559 out of 17168: 3 %
# Loading spam... 560 out of 17168: 3 %
# Loading spam... 561 out of 17168: 3 %
# Loading spam... 562 out of 17168: 3 %
# Loading spam... 563 out of 17168: 3 %
# Loading spam... 564 out of 17168: 3 %
# Loading spam... 565 out of 17168: 3 %
# Loading spam... 566 out of 17168: 3 %
# Loading spam... 567 out of 17168: 3 %
# Loading spam... 568 out of 17168: 3 %
# Loading spam... 569 out of 17168: 3 %
# Loading spam... 570 out of 17168: 3 %
# Loading spam... 571 out of 17168: 3 %
# Loading spam... 572 out of 17168: 3 %
# Loading spam... 573 out of 17168: 3 %
# Loading spam... 574 out of 17168: 3 %
# Loading spam... 575 out of 17168: 3 %
# Loading spam... 576 out of 17168: 3 %
# Loading spam... 577 out of 17168: 3 %
# Loading spam... 578 out of 17168: 3 %
# Loading spam... 579 out of 17168: 3 %
# Loading spam... 580 out of 17168: 3 %
# Loading spam... 581 out of 17168: 3 %
# Loading spam... 582 out of 17168: 3 %
# Loading spam... 583 out of 17168: 3 %
# Loading spam... 584 out of 17168: 3 %
# Loading spam... 585 out of 17168: 3 %
# Loading spam... 586 out of 17168: 3 %
# Loading spam... 587 out of 17168: 3 %
# Loading spam... 588 out of 17168: 3 %
# Loading spam... 589 out of 17168: 3 %
# Loading spam... 590 out of 17168: 3 %
# Loading spam... 591 out of 17168: 3 %
# Loading spam... 592 out of 17168: 3 %
# Loading spam... 593 out of 17168: 3 %
# Loading spam... 594 out of 17168: 3 %
# Loading spam... 595 out of 17168: 3 %
# Loading spam... 596 out of 17168: 3 %
# Loading spam... 597 out of 17168: 3 %
# Loading spam... 598 out of 17168: 3 %
# Loading spam... 599 out of 17168: 3 %
# Loading spam... 600 out of 17168: 3 %
# Loading spam... 601 out of 17168: 3 %
# Loading spam... 602 out of 17168: 3 %
# Loading spam... 603 out of 17168: 3 %
# Loading spam... 604 out of 17168: 3 %
# Loading spam... 605 out of 17168: 3 %
# Loading spam... 606 out of 17168: 3 %
# Loading spam... 607 out of 17168: 3 %
# Loading spam... 608 out of 17168: 3 %
# Loading spam... 609 out of 17168: 3 %
# Loading spam... 610 out of 17168: 3 %
# Loading spam... 611 out of 17168: 3 %
# Loading spam... 612 out of 17168: 3 %
# Loading spam... 613 out of 17168: 3 %
# Loading spam... 614 out of 17168: 3 %
# Loading spam... 615 out of 17168: 3 %
# Loading spam... 616 out of 17168: 3 %
# Loading spam... 617 out of 17168: 3 %
# Loading spam... 618 out of 17168: 3 %
# Loading spam... 619 out of 17168: 3 %
# Loading spam... 620 out of 17168: 3 %
# Loading spam... 621 out of 17168: 3 %
# Loading spam... 622 out of 17168: 3 %
# Loading spam... 623 out of 17168: 3 %
# Loading spam... 624 out of 17168: 3 %
# Loading spam... 625 out of 17168: 3 %
# Loading spam... 626 out of 17168: 3 %
# Loading spam... 627 out of 17168: 3 %
# Loading spam... 628 out of 17168: 3 %
# Loading spam... 629 out of 17168: 3 %
# Loading spam... 630 out of 17168: 3 %
# Loading spam... 631 out of 17168: 3 %
# Loading spam... 632 out of 17168: 3 %
# Loading spam... 633 out of 17168: 3 %
# Loading spam... 634 out of 17168: 3 %
# Loading spam... 635 out of 17168: 3 %
# Loading spam... 636 out of 17168: 3 %
# Loading spam... 637 out of 17168: 3 %
# Loading spam... 638 out of 17168: 3 %
# Loading spam... 639 out of 17168: 3 %
# Loading spam... 640 out of 17168: 3 %
# Loading spam... 641 out of 17168: 3 %
# Loading spam... 642 out of 17168: 3 %
# Loading spam... 643 out of 17168: 3 %
# Loading spam... 644 out of 17168: 3 %
# Loading spam... 645 out of 17168: 3 %
# Loading spam... 646 out of 17168: 3 %
# Loading spam... 647 out of 17168: 3 %
# Loading spam... 648 out of 17168: 3 %
# Loading spam... 649 out of 17168: 3 %
# Loading spam... 650 out of 17168: 3 %
# Loading spam... 651 out of 17168: 3 %
# Loading spam... 652 out of 17168: 3 %
# Loading spam... 653 out of 17168: 3 %
# Loading spam... 654 out of 17168: 3 %
# Loading spam... 655 out of 17168: 3 %
# Loading spam... 656 out of 17168: 3 %
# Loading spam... 657 out of 17168: 3 %
# Loading spam... 658 out of 17168: 3 %
# Loading spam... 659 out of 17168: 3 %
# Loading spam... 660 out of 17168: 3 %
# Loading spam... 661 out of 17168: 3 %
# Loading spam... 662 out of 17168: 3 %
# Loading spam... 663 out of 17168: 3 %
# Loading spam... 664 out of 17168: 3 %
# Loading spam... 665 out of 17168: 3 %
# Loading spam... 666 out of 17168: 3 %
# Loading spam... 667 out of 17168: 3 %
# Loading spam... 668 out of 17168: 3 %
# Loading spam... 669 out of 17168: 3 %
# Loading spam... 670 out of 17168: 3 %
# Loading spam... 671 out of 17168: 3 %
# Loading spam... 672 out of 17168: 3 %
# Loading spam... 673 out of 17168: 3 %
# Loading spam... 674 out of 17168: 3 %
# Loading spam... 675 out of 17168: 3 %
# Loading spam... 676 out of 17168: 3 %
# Loading spam... 677 out of 17168: 3 %
# Loading spam... 678 out of 17168: 3 %
# Loading spam... 679 out of 17168: 3 %
# Loading spam... 680 out of 17168: 3 %
# Loading spam... 681 out of 17168: 3 %
# Loading spam... 682 out of 17168: 3 %
# Loading spam... 683 out of 17168: 3 %
# Loading spam... 684 out of 17168: 3 %
# Loading spam... 685 out of 17168: 3 %
# Loading spam... 686 out of 17168: 3 %
# Loading spam... 687 out of 17168: 4 %
# Loading spam... 688 out of 17168: 4 %
# Loading spam... 689 out of 17168: 4 %
# Loading spam... 690 out of 17168: 4 %
# Loading spam... 691 out of 17168: 4 %
# Loading spam... 692 out of 17168: 4 %
# Loading spam... 693 out of 17168: 4 %
# Loading spam... 694 out of 17168: 4 %
# Loading spam... 695 out of 17168: 4 %
# Loading spam... 696 out of 17168: 4 %
# Loading spam... 697 out of 17168: 4 %
# Loading spam... 698 out of 17168: 4 %
# Loading spam... 699 out of 17168: 4 %
# Loading spam... 700 out of 17168: 4 %
# Loading spam... 701 out of 17168: 4 %
# Loading spam... 702 out of 17168: 4 %
# Loading spam... 703 out of 17168: 4 %
# Loading spam... 704 out of 17168: 4 %
# Loading spam... 705 out of 17168: 4 %
# Loading spam... 706 out of 17168: 4 %
# Loading spam... 707 out of 17168: 4 %
# Loading spam... 708 out of 17168: 4 %
# Loading spam... 709 out of 17168: 4 %
# Loading spam... 710 out of 17168: 4 %
# Loading spam... 711 out of 17168: 4 %
# Loading spam... 712 out of 17168: 4 %
# Loading spam... 713 out of 17168: 4 %
# Loading spam... 714 out of 17168: 4 %
# Loading spam... 715 out of 17168: 4 %
# Loading spam... 716 out of 17168: 4 %
# Loading spam... 717 out of 17168: 4 %
# Loading spam... 718 out of 17168: 4 %
# Loading spam... 719 out of 17168: 4 %
# Loading spam... 720 out of 17168: 4 %
# Loading spam... 721 out of 17168: 4 %
# Loading spam... 722 out of 17168: 4 %
# Loading spam... 723 out of 17168: 4 %
# Loading spam... 724 out of 17168: 4 %
# Loading spam... 725 out of 17168: 4 %
# Loading spam... 726 out of 17168: 4 %
# Loading spam... 727 out of 17168: 4 %
# Loading spam... 728 out of 17168: 4 %
# Loading spam... 729 out of 17168: 4 %
# Loading spam... 730 out of 17168: 4 %
# Loading spam... 731 out of 17168: 4 %
# Loading spam... 732 out of 17168: 4 %
# Loading spam... 733 out of 17168: 4 %
# Loading spam... 734 out of 17168: 4 %
# Loading spam... 735 out of 17168: 4 %
# Loading spam... 736 out of 17168: 4 %
# Loading spam... 737 out of 17168: 4 %
# Loading spam... 738 out of 17168: 4 %
# Loading spam... 739 out of 17168: 4 %
# Loading spam... 740 out of 17168: 4 %
# Loading spam... 741 out of 17168: 4 %
# Loading spam... 742 out of 17168: 4 %
# Loading spam... 743 out of 17168: 4 %
# Loading spam... 744 out of 17168: 4 %
# Loading spam... 745 out of 17168: 4 %
# Loading spam... 746 out of 17168: 4 %
# Loading spam... 747 out of 17168: 4 %
# Loading spam... 748 out of 17168: 4 %
# Loading spam... 749 out of 17168: 4 %
# Loading spam... 750 out of 17168: 4 %
# Loading spam... 751 out of 17168: 4 %
# Loading spam... 752 out of 17168: 4 %
# Loading spam... 753 out of 17168: 4 %
# Loading spam... 754 out of 17168: 4 %
# Loading spam... 755 out of 17168: 4 %
# Loading spam... 756 out of 17168: 4 %
# Loading spam... 757 out of 17168: 4 %
# Loading spam... 758 out of 17168: 4 %
# Loading spam... 759 out of 17168: 4 %
# Loading spam... 760 out of 17168: 4 %
# Loading spam... 761 out of 17168: 4 %
# Loading spam... 762 out of 17168: 4 %
# Loading spam... 763 out of 17168: 4 %
# Loading spam... 764 out of 17168: 4 %
# Loading spam... 765 out of 17168: 4 %
# Loading spam... 766 out of 17168: 4 %
# Loading spam... 767 out of 17168: 4 %
# Loading spam... 768 out of 17168: 4 %
# Loading spam... 769 out of 17168: 4 %
# Loading spam... 770 out of 17168: 4 %
# Loading spam... 771 out of 17168: 4 %
# Loading spam... 772 out of 17168: 4 %
# Loading spam... 773 out of 17168: 4 %
# Loading spam... 774 out of 17168: 4 %
# Loading spam... 775 out of 17168: 4 %
# Loading spam... 776 out of 17168: 4 %
# Loading spam... 777 out of 17168: 4 %
# Loading spam... 778 out of 17168: 4 %
# Loading spam... 779 out of 17168: 4 %
# Loading spam... 780 out of 17168: 4 %
# Loading spam... 781 out of 17168: 4 %
# Loading spam... 782 out of 17168: 4 %
# Loading spam... 783 out of 17168: 4 %
# Loading spam... 784 out of 17168: 4 %
# Loading spam... 785 out of 17168: 4 %
# Loading spam... 786 out of 17168: 4 %
# Loading spam... 787 out of 17168: 4 %
# Loading spam... 788 out of 17168: 4 %
# Loading spam... 789 out of 17168: 4 %
# Loading spam... 790 out of 17168: 4 %
# Loading spam... 791 out of 17168: 4 %
# Loading spam... 792 out of 17168: 4 %
# Loading spam... 793 out of 17168: 4 %
# Loading spam... 794 out of 17168: 4 %
# Loading spam... 795 out of 17168: 4 %
# Loading spam... 796 out of 17168: 4 %
# Loading spam... 797 out of 17168: 4 %
# Loading spam... 798 out of 17168: 4 %
# Loading spam... 799 out of 17168: 4 %
# Loading spam... 800 out of 17168: 4 %
# Loading spam... 801 out of 17168: 4 %
# Loading spam... 802 out of 17168: 4 %
# Loading spam... 803 out of 17168: 4 %
# Loading spam... 804 out of 17168: 4 %
# Loading spam... 805 out of 17168: 4 %
# Loading spam... 806 out of 17168: 4 %
# Loading spam... 807 out of 17168: 4 %
# Loading spam... 808 out of 17168: 4 %
# Loading spam... 809 out of 17168: 4 %
# Loading spam... 810 out of 17168: 4 %
# Loading spam... 811 out of 17168: 4 %
# Loading spam... 812 out of 17168: 4 %
# Loading spam... 813 out of 17168: 4 %
# Loading spam... 814 out of 17168: 4 %
# Loading spam... 815 out of 17168: 4 %
# Loading spam... 816 out of 17168: 4 %
# Loading spam... 817 out of 17168: 4 %
# Loading spam... 818 out of 17168: 4 %
# Loading spam... 819 out of 17168: 4 %
# Loading spam... 820 out of 17168: 4 %
# Loading spam... 821 out of 17168: 4 %
# Loading spam... 822 out of 17168: 4 %
# Loading spam... 823 out of 17168: 4 %
# Loading spam... 824 out of 17168: 4 %
# Loading spam... 825 out of 17168: 4 %
# Loading spam... 826 out of 17168: 4 %
# Loading spam... 827 out of 17168: 4 %
# Loading spam... 828 out of 17168: 4 %
# Loading spam... 829 out of 17168: 4 %
# Loading spam... 830 out of 17168: 4 %
# Loading spam... 831 out of 17168: 4 %
# Loading spam... 832 out of 17168: 4 %
# Loading spam... 833 out of 17168: 4 %
# Loading spam... 834 out of 17168: 4 %
# Loading spam... 835 out of 17168: 4 %
# Loading spam... 836 out of 17168: 4 %
# Loading spam... 837 out of 17168: 4 %
# Loading spam... 838 out of 17168: 4 %
# Loading spam... 839 out of 17168: 4 %
# Loading spam... 840 out of 17168: 4 %
# Loading spam... 841 out of 17168: 4 %
# Loading spam... 842 out of 17168: 4 %
# Loading spam... 843 out of 17168: 4 %
# Loading spam... 844 out of 17168: 4 %
# Loading spam... 845 out of 17168: 4 %
# Loading spam... 846 out of 17168: 4 %
# Loading spam... 847 out of 17168: 4 %
# Loading spam... 848 out of 17168: 4 %
# Loading spam... 849 out of 17168: 4 %
# Loading spam... 850 out of 17168: 4 %
# Loading spam... 851 out of 17168: 4 %
# Loading spam... 852 out of 17168: 4 %
# Loading spam... 853 out of 17168: 4 %
# Loading spam... 854 out of 17168: 4 %
# Loading spam... 855 out of 17168: 4 %
# Loading spam... 856 out of 17168: 4 %
# Loading spam... 857 out of 17168: 4 %
# Loading spam... 858 out of 17168: 4 %
# Loading spam... 859 out of 17168: 5 %
# Loading spam... 860 out of 17168: 5 %
# Loading spam... 861 out of 17168: 5 %
# Loading spam... 862 out of 17168: 5 %
# Loading spam... 863 out of 17168: 5 %
# Loading spam... 864 out of 17168: 5 %
# Loading spam... 865 out of 17168: 5 %
# Loading spam... 866 out of 17168: 5 %
# Loading spam... 867 out of 17168: 5 %
# Loading spam... 868 out of 17168: 5 %
# Loading spam... 869 out of 17168: 5 %
# Loading spam... 870 out of 17168: 5 %
# Loading spam... 871 out of 17168: 5 %
# Loading spam... 872 out of 17168: 5 %
# Loading spam... 873 out of 17168: 5 %
# Loading spam... 874 out of 17168: 5 %
# Loading spam... 875 out of 17168: 5 %
# Loading spam... 876 out of 17168: 5 %
# Loading spam... 877 out of 17168: 5 %
# Loading spam... 878 out of 17168: 5 %
# Loading spam... 879 out of 17168: 5 %
# Loading spam... 880 out of 17168: 5 %
# Loading spam... 881 out of 17168: 5 %
# Loading spam... 882 out of 17168: 5 %
# Loading spam... 883 out of 17168: 5 %
# Loading spam... 884 out of 17168: 5 %
# Loading spam... 885 out of 17168: 5 %
# Loading spam... 886 out of 17168: 5 %
# Loading spam... 887 out of 17168: 5 %
# Loading spam... 888 out of 17168: 5 %
# Loading spam... 889 out of 17168: 5 %
# Loading spam... 890 out of 17168: 5 %
# Loading spam... 891 out of 17168: 5 %
# Loading spam... 892 out of 17168: 5 %
# Loading spam... 893 out of 17168: 5 %
# Loading spam... 894 out of 17168: 5 %
# Loading spam... 895 out of 17168: 5 %
# Loading spam... 896 out of 17168: 5 %
# Loading spam... 897 out of 17168: 5 %
# Loading spam... 898 out of 17168: 5 %
# Loading spam... 899 out of 17168: 5 %
# Loading spam... 900 out of 17168: 5 %
# Loading spam... 901 out of 17168: 5 %
# Loading spam... 902 out of 17168: 5 %
# Loading spam... 903 out of 17168: 5 %
# Loading spam... 904 out of 17168: 5 %
# Loading spam... 905 out of 17168: 5 %
# Loading spam... 906 out of 17168: 5 %
# Loading spam... 907 out of 17168: 5 %
# Loading spam... 908 out of 17168: 5 %
# Loading spam... 909 out of 17168: 5 %
# Loading spam... 910 out of 17168: 5 %
# Loading spam... 911 out of 17168: 5 %
# Loading spam... 912 out of 17168: 5 %
# Loading spam... 913 out of 17168: 5 %
# Loading spam... 914 out of 17168: 5 %
# Loading spam... 915 out of 17168: 5 %
# Loading spam... 916 out of 17168: 5 %
# Loading spam... 917 out of 17168: 5 %
# Loading spam... 918 out of 17168: 5 %
# Loading spam... 919 out of 17168: 5 %
# Loading spam... 920 out of 17168: 5 %
# Loading spam... 921 out of 17168: 5 %
# Loading spam... 922 out of 17168: 5 %
# Loading spam... 923 out of 17168: 5 %
# Loading spam... 924 out of 17168: 5 %
# Loading spam... 925 out of 17168: 5 %
# Loading spam... 926 out of 17168: 5 %
# Loading spam... 927 out of 17168: 5 %
# Loading spam... 928 out of 17168: 5 %
# Loading spam... 929 out of 17168: 5 %
# Loading spam... 930 out of 17168: 5 %
# Loading spam... 931 out of 17168: 5 %
# Loading spam... 932 out of 17168: 5 %
# Loading spam... 933 out of 17168: 5 %
# Loading spam... 934 out of 17168: 5 %
# Loading spam... 935 out of 17168: 5 %
# Loading spam... 936 out of 17168: 5 %
# Loading spam... 937 out of 17168: 5 %
# Loading spam... 938 out of 17168: 5 %
# Loading spam... 939 out of 17168: 5 %
# Loading spam... 940 out of 17168: 5 %
# Loading spam... 941 out of 17168: 5 %
# Loading spam... 942 out of 17168: 5 %
# Loading spam... 943 out of 17168: 5 %
# Loading spam... 944 out of 17168: 5 %
# Loading spam... 945 out of 17168: 5 %
# Loading spam... 946 out of 17168: 5 %
# Loading spam... 947 out of 17168: 5 %
# Loading spam... 948 out of 17168: 5 %
# Loading spam... 949 out of 17168: 5 %
# Loading spam... 950 out of 17168: 5 %
# Loading spam... 951 out of 17168: 5 %
# Loading spam... 952 out of 17168: 5 %
# Loading spam... 953 out of 17168: 5 %
# Loading spam... 954 out of 17168: 5 %
# Loading spam... 955 out of 17168: 5 %
# Loading spam... 956 out of 17168: 5 %
# Loading spam... 957 out of 17168: 5 %
# Loading spam... 958 out of 17168: 5 %
# Loading spam... 959 out of 17168: 5 %
# Loading spam... 960 out of 17168: 5 %
# Loading spam... 961 out of 17168: 5 %
# Loading spam... 962 out of 17168: 5 %
# Loading spam... 963 out of 17168: 5 %
# Loading spam... 964 out of 17168: 5 %
# Loading spam... 965 out of 17168: 5 %
# Loading spam... 966 out of 17168: 5 %
# Loading spam... 967 out of 17168: 5 %
# Loading spam... 968 out of 17168: 5 %
# Loading spam... 969 out of 17168: 5 %
# Loading spam... 970 out of 17168: 5 %
# Loading spam... 971 out of 17168: 5 %
# Loading spam... 972 out of 17168: 5 %
# Loading spam... 973 out of 17168: 5 %
# Loading spam... 974 out of 17168: 5 %
# Loading spam... 975 out of 17168: 5 %
# Loading spam... 976 out of 17168: 5 %
# Loading spam... 977 out of 17168: 5 %
# Loading spam... 978 out of 17168: 5 %
# Loading spam... 979 out of 17168: 5 %
# Loading spam... 980 out of 17168: 5 %
# Loading spam... 981 out of 17168: 5 %
# Loading spam... 982 out of 17168: 5 %
# Loading spam... 983 out of 17168: 5 %
# Loading spam... 984 out of 17168: 5 %
# Loading spam... 985 out of 17168: 5 %
# Loading spam... 986 out of 17168: 5 %
# Loading spam... 987 out of 17168: 5 %
# Loading spam... 988 out of 17168: 5 %
# Loading spam... 989 out of 17168: 5 %
# Loading spam... 990 out of 17168: 5 %
# Loading spam... 991 out of 17168: 5 %
# Loading spam... 992 out of 17168: 5 %
# Loading spam... 993 out of 17168: 5 %
# Loading spam... 994 out of 17168: 5 %
# Loading spam... 995 out of 17168: 5 %
# Loading spam... 996 out of 17168: 5 %
# Loading spam... 997 out of 17168: 5 %
# Loading spam... 998 out of 17168: 5 %
# Loading spam... 999 out of 17168: 5 %
# Loading spam... 1000 out of 17168: 5 %
# Loading spam... 1001 out of 17168: 5 %
# Loading spam... 1002 out of 17168: 5 %
# Loading spam... 1003 out of 17168: 5 %
# Loading spam... 1004 out of 17168: 5 %
# Loading spam... 1005 out of 17168: 5 %
# Loading spam... 1006 out of 17168: 5 %
# Loading spam... 1007 out of 17168: 5 %
# Loading spam... 1008 out of 17168: 5 %
# Loading spam... 1009 out of 17168: 5 %
# Loading spam... 1010 out of 17168: 5 %
# Loading spam... 1011 out of 17168: 5 %
# Loading spam... 1012 out of 17168: 5 %
# Loading spam... 1013 out of 17168: 5 %
# Loading spam... 1014 out of 17168: 5 %
# Loading spam... 1015 out of 17168: 5 %
# Loading spam... 1016 out of 17168: 5 %
# Loading spam... 1017 out of 17168: 5 %
# Loading spam... 1018 out of 17168: 5 %
# Loading spam... 1019 out of 17168: 5 %
# Loading spam... 1020 out of 17168: 5 %
# Loading spam... 1021 out of 17168: 5 %
# Loading spam... 1022 out of 17168: 5 %
# Loading spam... 1023 out of 17168: 5 %
# Loading spam... 1024 out of 17168: 5 %
# Loading spam... 1025 out of 17168: 5 %
# Loading spam... 1026 out of 17168: 5 %
# Loading spam... 1027 out of 17168: 5 %
# Loading spam... 1028 out of 17168: 5 %
# Loading spam... 1029 out of 17168: 5 %
# Loading spam... 1030 out of 17168: 5 %
# Loading spam... 1031 out of 17168: 6 %
# Loading spam... 1032 out of 17168: 6 %
# Loading spam... 1033 out of 17168: 6 %
# Loading spam... 1034 out of 17168: 6 %
# Loading spam... 1035 out of 17168: 6 %
# Loading spam... 1036 out of 17168: 6 %
# Loading spam... 1037 out of 17168: 6 %
# Loading spam... 1038 out of 17168: 6 %
# Loading spam... 1039 out of 17168: 6 %
# Loading spam... 1040 out of 17168: 6 %
# Loading spam... 1041 out of 17168: 6 %
# Loading spam... 1042 out of 17168: 6 %
# Loading spam... 1043 out of 17168: 6 %
# Loading spam... 1044 out of 17168: 6 %
# Loading spam... 1045 out of 17168: 6 %
# Loading spam... 1046 out of 17168: 6 %
# Loading spam... 1047 out of 17168: 6 %
# Loading spam... 1048 out of 17168: 6 %
# Loading spam... 1049 out of 17168: 6 %
# Loading spam... 1050 out of 17168: 6 %
# Loading spam... 1051 out of 17168: 6 %
# Loading spam... 1052 out of 17168: 6 %
# Loading spam... 1053 out of 17168: 6 %
# Loading spam... 1054 out of 17168: 6 %
# Loading spam... 1055 out of 17168: 6 %
# Loading spam... 1056 out of 17168: 6 %
# Loading spam... 1057 out of 17168: 6 %
# Loading spam... 1058 out of 17168: 6 %
# Loading spam... 1059 out of 17168: 6 %
# Loading spam... 1060 out of 17168: 6 %
# Loading spam... 1061 out of 17168: 6 %
# Loading spam... 1062 out of 17168: 6 %
# Loading spam... 1063 out of 17168: 6 %
# Loading spam... 1064 out of 17168: 6 %
# Loading spam... 1065 out of 17168: 6 %
# Loading spam... 1066 out of 17168: 6 %
# Loading spam... 1067 out of 17168: 6 %
# Loading spam... 1068 out of 17168: 6 %
# Loading spam... 1069 out of 17168: 6 %
# Loading spam... 1070 out of 17168: 6 %
# Loading spam... 1071 out of 17168: 6 %
# Loading spam... 1072 out of 17168: 6 %
# Loading spam... 1073 out of 17168: 6 %
# Loading spam... 1074 out of 17168: 6 %
# Loading spam... 1075 out of 17168: 6 %
# Loading spam... 1076 out of 17168: 6 %
# Loading spam... 1077 out of 17168: 6 %
# Loading spam... 1078 out of 17168: 6 %
# Loading spam... 1079 out of 17168: 6 %
# Loading spam... 1080 out of 17168: 6 %
# Loading spam... 1081 out of 17168: 6 %
# Loading spam... 1082 out of 17168: 6 %
# Loading spam... 1083 out of 17168: 6 %
# Loading spam... 1084 out of 17168: 6 %
# Loading spam... 1085 out of 17168: 6 %
# Loading spam... 1086 out of 17168: 6 %
# Loading spam... 1087 out of 17168: 6 %
# Loading spam... 1088 out of 17168: 6 %
# Loading spam... 1089 out of 17168: 6 %
# Loading spam... 1090 out of 17168: 6 %
# Loading spam... 1091 out of 17168: 6 %
# Loading spam... 1092 out of 17168: 6 %
# Loading spam... 1093 out of 17168: 6 %
# Loading spam... 1094 out of 17168: 6 %
# Loading spam... 1095 out of 17168: 6 %
# Loading spam... 1096 out of 17168: 6 %
# Loading spam... 1097 out of 17168: 6 %
# Loading spam... 1098 out of 17168: 6 %
# Loading spam... 1099 out of 17168: 6 %
# Loading spam... 1100 out of 17168: 6 %
# Loading spam... 1101 out of 17168: 6 %
# Loading spam... 1102 out of 17168: 6 %
# Loading spam... 1103 out of 17168: 6 %
# Loading spam... 1104 out of 17168: 6 %
# Loading spam... 1105 out of 17168: 6 %
# Loading spam... 1106 out of 17168: 6 %
# Loading spam... 1107 out of 17168: 6 %
# Loading spam... 1108 out of 17168: 6 %
# Loading spam... 1109 out of 17168: 6 %
# Loading spam... 1110 out of 17168: 6 %
# Loading spam... 1111 out of 17168: 6 %
# Loading spam... 1112 out of 17168: 6 %
# Loading spam... 1113 out of 17168: 6 %
# Loading spam... 1114 out of 17168: 6 %
# Loading spam... 1115 out of 17168: 6 %
# Loading spam... 1116 out of 17168: 6 %
# Loading spam... 1117 out of 17168: 6 %
# Loading spam... 1118 out of 17168: 6 %
# Loading spam... 1119 out of 17168: 6 %
# Loading spam... 1120 out of 17168: 6 %
# Loading spam... 1121 out of 17168: 6 %
# Loading spam... 1122 out of 17168: 6 %
# Loading spam... 1123 out of 17168: 6 %
# Loading spam... 1124 out of 17168: 6 %
# Loading spam... 1125 out of 17168: 6 %
# Loading spam... 1126 out of 17168: 6 %
# Loading spam... 1127 out of 17168: 6 %
# Loading spam... 1128 out of 17168: 6 %
# Loading spam... 1129 out of 17168: 6 %
# Loading spam... 1130 out of 17168: 6 %
# Loading spam... 1131 out of 17168: 6 %
# Loading spam... 1132 out of 17168: 6 %
# Loading spam... 1133 out of 17168: 6 %
# Loading spam... 1134 out of 17168: 6 %
# Loading spam... 1135 out of 17168: 6 %
# Loading spam... 1136 out of 17168: 6 %
# Loading spam... 1137 out of 17168: 6 %
# Loading spam... 1138 out of 17168: 6 %
# Loading spam... 1139 out of 17168: 6 %
# Loading spam... 1140 out of 17168: 6 %
# Loading spam... 1141 out of 17168: 6 %
# Loading spam... 1142 out of 17168: 6 %
# Loading spam... 1143 out of 17168: 6 %
# Loading spam... 1144 out of 17168: 6 %
# Loading spam... 1145 out of 17168: 6 %
# Loading spam... 1146 out of 17168: 6 %
# Loading spam... 1147 out of 17168: 6 %
# Loading spam... 1148 out of 17168: 6 %
# Loading spam... 1149 out of 17168: 6 %
# Loading spam... 1150 out of 17168: 6 %
# Loading spam... 1151 out of 17168: 6 %
# Loading spam... 1152 out of 17168: 6 %
# Loading spam... 1153 out of 17168: 6 %
# Loading spam... 1154 out of 17168: 6 %
# Loading spam... 1155 out of 17168: 6 %
# Loading spam... 1156 out of 17168: 6 %
# Loading spam... 1157 out of 17168: 6 %
# Loading spam... 1158 out of 17168: 6 %
# Loading spam... 1159 out of 17168: 6 %
# Loading spam... 1160 out of 17168: 6 %
# Loading spam... 1161 out of 17168: 6 %
# Loading spam... 1162 out of 17168: 6 %
# Loading spam... 1163 out of 17168: 6 %
# Loading spam... 1164 out of 17168: 6 %
# Loading spam... 1165 out of 17168: 6 %
# Loading spam... 1166 out of 17168: 6 %
# Loading spam... 1167 out of 17168: 6 %
# Loading spam... 1168 out of 17168: 6 %
# Loading spam... 1169 out of 17168: 6 %
# Loading spam... 1170 out of 17168: 6 %
# Loading spam... 1171 out of 17168: 6 %
# Loading spam... 1172 out of 17168: 6 %
# Loading spam... 1173 out of 17168: 6 %
# Loading spam... 1174 out of 17168: 6 %
# Loading spam... 1175 out of 17168: 6 %
# Loading spam... 1176 out of 17168: 6 %
# Loading spam... 1177 out of 17168: 6 %
# Loading spam... 1178 out of 17168: 6 %
# Loading spam... 1179 out of 17168: 6 %
# Loading spam... 1180 out of 17168: 6 %
# Loading spam... 1181 out of 17168: 6 %
# Loading spam... 1182 out of 17168: 6 %
# Loading spam... 1183 out of 17168: 6 %
# Loading spam... 1184 out of 17168: 6 %
# Loading spam... 1185 out of 17168: 6 %
# Loading spam... 1186 out of 17168: 6 %
# Loading spam... 1187 out of 17168: 6 %
# Loading spam... 1188 out of 17168: 6 %
# Loading spam... 1189 out of 17168: 6 %
# Loading spam... 1190 out of 17168: 6 %
# Loading spam... 1191 out of 17168: 6 %
# Loading spam... 1192 out of 17168: 6 %
# Loading spam... 1193 out of 17168: 6 %
# Loading spam... 1194 out of 17168: 6 %
# Loading spam... 1195 out of 17168: 6 %
# Loading spam... 1196 out of 17168: 6 %
# Loading spam... 1197 out of 17168: 6 %
# Loading spam... 1198 out of 17168: 6 %
# Loading spam... 1199 out of 17168: 6 %
# Loading spam... 1200 out of 17168: 6 %
# Loading spam... 1201 out of 17168: 6 %
# Loading spam... 1202 out of 17168: 7 %
# Loading spam... 1203 out of 17168: 7 %
# Loading spam... 1204 out of 17168: 7 %
# Loading spam... 1205 out of 17168: 7 %
# Loading spam... 1206 out of 17168: 7 %
# Loading spam... 1207 out of 17168: 7 %
# Loading spam... 1208 out of 17168: 7 %
# Loading spam... 1209 out of 17168: 7 %
# Loading spam... 1210 out of 17168: 7 %
# Loading spam... 1211 out of 17168: 7 %
# Loading spam... 1212 out of 17168: 7 %
# Loading spam... 1213 out of 17168: 7 %
# Loading spam... 1214 out of 17168: 7 %
# Loading spam... 1215 out of 17168: 7 %
# Loading spam... 1216 out of 17168: 7 %
# Loading spam... 1217 out of 17168: 7 %
# Loading spam... 1218 out of 17168: 7 %
# Loading spam... 1219 out of 17168: 7 %
# Loading spam... 1220 out of 17168: 7 %
# Loading spam... 1221 out of 17168: 7 %
# Loading spam... 1222 out of 17168: 7 %
# Loading spam... 1223 out of 17168: 7 %
# Loading spam... 1224 out of 17168: 7 %
# Loading spam... 1225 out of 17168: 7 %
# Loading spam... 1226 out of 17168: 7 %
# Loading spam... 1227 out of 17168: 7 %
# Loading spam... 1228 out of 17168: 7 %
# Loading spam... 1229 out of 17168: 7 %
# Loading spam... 1230 out of 17168: 7 %
# Loading spam... 1231 out of 17168: 7 %
# Loading spam... 1232 out of 17168: 7 %
# Loading spam... 1233 out of 17168: 7 %
# Loading spam... 1234 out of 17168: 7 %
# Loading spam... 1235 out of 17168: 7 %
# Loading spam... 1236 out of 17168: 7 %
# Loading spam... 1237 out of 17168: 7 %
# Loading spam... 1238 out of 17168: 7 %
# Loading spam... 1239 out of 17168: 7 %
# Loading spam... 1240 out of 17168: 7 %
# Loading spam... 1241 out of 17168: 7 %
# Loading spam... 1242 out of 17168: 7 %
# Loading spam... 1243 out of 17168: 7 %
# Loading spam... 1244 out of 17168: 7 %
# Loading spam... 1245 out of 17168: 7 %
# Loading spam... 1246 out of 17168: 7 %
# Loading spam... 1247 out of 17168: 7 %
# Loading spam... 1248 out of 17168: 7 %
# Loading spam... 1249 out of 17168: 7 %
# Loading spam... 1250 out of 17168: 7 %
# Loading spam... 1251 out of 17168: 7 %
# Loading spam... 1252 out of 17168: 7 %
# Loading spam... 1253 out of 17168: 7 %
# Loading spam... 1254 out of 17168: 7 %
# ...
# Loading ham... 7097 out of 16545: 42 %
# Loading ham... 7098 out of 16545: 42 %
# Loading ham... 7099 out of 16545: 42 %
# Loading ham... 7100 out of 16545: 42 %
# Loading ham... 7101 out of 16545: 42 %
# Loading ham... 7102 out of 16545: 42 %
# Loading ham... 7103 out of 16545: 42 %
# Loading ham... 7104 out of 16545: 42 %
# Loading ham... 7105 out of 16545: 42 %
# Loading ham... 7106 out of 16545: 42 %
# Loading ham... 7107 out of 16545: 42 %
# Loading ham... 7108 out of 16545: 42 %
# Loading ham... 7109 out of 16545: 42 %
# Loading ham... 7110 out of 16545: 42 %
# Loading ham... 7111 out of 16545: 42 %
# Loading ham... 7112 out of 16545: 42 %
# Loading ham... 7113 out of 16545: 42 %
# Loading ham... 7114 out of 16545: 42 %
# Loading ham... 7115 out of 16545: 43 %
# Loading ham... 7116 out of 16545: 43 %
# Loading ham... 7117 out of 16545: 43 %
# Loading ham... 7118 out of 16545: 43 %
# Loading ham... 7119 out of 16545: 43 %
# Loading ham... 7120 out of 16545: 43 %
# Loading ham... 7121 out of 16545: 43 %
# Loading ham... 7122 out of 16545: 43 %
# Loading ham... 7123 out of 16545: 43 %
# Loading ham... 7124 out of 16545: 43 %
# Loading ham... 7125 out of 16545: 43 %
# Loading ham... 7126 out of 16545: 43 %
# Loading ham... 7127 out of 16545: 43 %
# Loading ham... 7128 out of 16545: 43 %
# Loading ham... 7129 out of 16545: 43 %
# Loading ham... 7130 out of 16545: 43 %
# Loading ham... 7131 out of 16545: 43 %
# Loading ham... 7132 out of 16545: 43 %
# Loading ham... 7133 out of 16545: 43 %
# Loading ham... 7134 out of 16545: 43 %
# Loading ham... 7135 out of 16545: 43 %
# Loading ham... 7136 out of 16545: 43 %
# Loading ham... 7137 out of 16545: 43 %
# Loading ham... 7138 out of 16545: 43 %
# Loading ham... 7139 out of 16545: 43 %
# Loading ham... 7140 out of 16545: 43 %
# Loading ham... 7141 out of 16545: 43 %
# Loading ham... 7142 out of 16545: 43 %
# Loading ham... 7143 out of 16545: 43 %
# Loading ham... 7144 out of 16545: 43 %
# Loading ham... 7145 out of 16545: 43 %
# Loading ham... 7146 out of 16545: 43 %
# Loading ham... 7147 out of 16545: 43 %
# Loading ham... 7148 out of 16545: 43 %
# Loading ham... 7149 out of 16545: 43 %
# Loading ham... 7150 out of 16545: 43 %
# Loading ham... 7151 out of 16545: 43 %
# Loading ham... 7152 out of 16545: 43 %
# Loading ham... 7153 out of 16545: 43 %
# Loading ham... 7154 out of 16545: 43 %
# Loading ham... 7155 out of 16545: 43 %
# Loading ham... 7156 out of 16545: 43 %
# Loading ham... 7157 out of 16545: 43 %
# Loading ham... 7158 out of 16545: 43 %
# Loading ham... 7159 out of 16545: 43 %
# Loading ham... 7160 out of 16545: 43 %
# Loading ham... 7161 out of 16545: 43 %
# Loading ham... 7162 out of 16545: 43 %
# Loading ham... 7163 out of 16545: 43 %
# Loading ham... 7164 out of 16545: 43 %
# Loading ham... 7165 out of 16545: 43 %
# Loading ham... 7166 out of 16545: 43 %
# Loading ham... 7167 out of 16545: 43 %
# Loading ham... 7168 out of 16545: 43 %
# Loading ham... 7169 out of 16545: 43 %
# Loading ham... 7170 out of 16545: 43 %
# Loading ham... 7171 out of 16545: 43 %
# Loading ham... 7172 out of 16545: 43 %
# Loading ham... 7173 out of 16545: 43 %
# Loading ham... 7174 out of 16545: 43 %
# Loading ham... 7175 out of 16545: 43 %
# Loading ham... 7176 out of 16545: 43 %
# Loading ham... 7177 out of 16545: 43 %
# Loading ham... 7178 out of 16545: 43 %
# Loading ham... 7179 out of 16545: 43 %
# Loading ham... 7180 out of 16545: 43 %
# Loading ham... 7181 out of 16545: 43 %
# Loading ham... 7182 out of 16545: 43 %
# Loading ham... 7183 out of 16545: 43 %
# Loading ham... 7184 out of 16545: 43 %
# Loading ham... 7185 out of 16545: 43 %
# Loading ham... 7186 out of 16545: 43 %
# Loading ham... 7187 out of 16545: 43 %
# Loading ham... 7188 out of 16545: 43 %
# Loading ham... 7189 out of 16545: 43 %
# Loading ham... 7190 out of 16545: 43 %
# Loading ham... 7191 out of 16545: 43 %
# Loading ham... 7192 out of 16545: 43 %
# Loading ham... 7193 out of 16545: 43 %
# Loading ham... 7194 out of 16545: 43 %
# Loading ham... 7195 out of 16545: 43 %
# Loading ham... 7196 out of 16545: 43 %
# Loading ham... 7197 out of 16545: 43 %
# Loading ham... 7198 out of 16545: 43 %
# Loading ham... 7199 out of 16545: 43 %
# Loading ham... 7200 out of 16545: 43 %
# Loading ham... 7201 out of 16545: 43 %
# Loading ham... 7202 out of 16545: 43 %
# Loading ham... 7203 out of 16545: 43 %
# Loading ham... 7204 out of 16545: 43 %
# Loading ham... 7205 out of 16545: 43 %
# Loading ham... 7206 out of 16545: 43 %
# Loading ham... 7207 out of 16545: 43 %
# Loading ham... 7208 out of 16545: 43 %
# Loading ham... 7209 out of 16545: 43 %
# Loading ham... 7210 out of 16545: 43 %
# Loading ham... 7211 out of 16545: 43 %
# Loading ham... 7212 out of 16545: 43 %
# Loading ham... 7213 out of 16545: 43 %
# Loading ham... 7214 out of 16545: 43 %
# Loading ham... 7215 out of 16545: 43 %
# Loading ham... 7216 out of 16545: 43 %
# Loading ham... 7217 out of 16545: 43 %
# Loading ham... 7218 out of 16545: 43 %
# Loading ham... 7219 out of 16545: 43 %
# Loading ham... 7220 out of 16545: 43 %
# Loading ham... 7221 out of 16545: 43 %
# Loading ham... 7222 out of 16545: 43 %
# Loading ham... 7223 out of 16545: 43 %
# Loading ham... 7224 out of 16545: 43 %
# Loading ham... 7225 out of 16545: 43 %
# Loading ham... 7226 out of 16545: 43 %
# Loading ham... 7227 out of 16545: 43 %
# Loading ham... 7228 out of 16545: 43 %
# Loading ham... 7229 out of 16545: 43 %
# Loading ham... 7230 out of 16545: 43 %
# Loading ham... 7231 out of 16545: 43 %
# Loading ham... 7232 out of 16545: 43 %
# Loading ham... 7233 out of 16545: 43 %
# Loading ham... 7234 out of 16545: 43 %
# Loading ham... 7235 out of 16545: 43 %
# Loading ham... 7236 out of 16545: 43 %
# Loading ham... 7237 out of 16545: 43 %
# Loading ham... 7238 out of 16545: 43 %
# Loading ham... 7239 out of 16545: 43 %
# Loading ham... 7240 out of 16545: 43 %
# Loading ham... 7241 out of 16545: 43 %
# Loading ham... 7242 out of 16545: 43 %
# Loading ham... 7243 out of 16545: 43 %
# Loading ham... 7244 out of 16545: 43 %
# Loading ham... 7245 out of 16545: 43 %
# Loading ham... 7246 out of 16545: 43 %
# Loading ham... 7247 out of 16545: 43 %
# Loading ham... 7248 out of 16545: 43 %
# Loading ham... 7249 out of 16545: 43 %
# Loading ham... 7250 out of 16545: 43 %
# Loading ham... 7251 out of 16545: 43 %
# Loading ham... 7252 out of 16545: 43 %
# Loading ham... 7253 out of 16545: 43 %
# Loading ham... 7254 out of 16545: 43 %
# Loading ham... 7255 out of 16545: 43 %
# Loading ham... 7256 out of 16545: 43 %
# Loading ham... 7257 out of 16545: 43 %
# Loading ham... 7258 out of 16545: 43 %
# Loading ham... 7259 out of 16545: 43 %
# Loading ham... 7260 out of 16545: 43 %
# Loading ham... 7261 out of 16545: 43 %
# Loading ham... 7262 out of 16545: 43 %
# Loading ham... 7263 out of 16545: 43 %
# Loading ham... 7264 out of 16545: 43 %
# Loading ham... 7265 out of 16545: 43 %
# Loading ham... 7266 out of 16545: 43 %
# Loading ham... 7267 out of 16545: 43 %
# Loading ham... 7268 out of 16545: 43 %
# Loading ham... 7269 out of 16545: 43 %
# Loading ham... 7270 out of 16545: 43 %
# Loading ham... 7271 out of 16545: 43 %
# Loading ham... 7272 out of 16545: 43 %
# Loading ham... 7273 out of 16545: 43 %
# Loading ham... 7274 out of 16545: 43 %
# Loading ham... 7275 out of 16545: 43 %
# Loading ham... 7276 out of 16545: 43 %
# Loading ham... 7277 out of 16545: 43 %
# Loading ham... 7278 out of 16545: 43 %
# Loading ham... 7279 out of 16545: 43 %
# Loading ham... 7280 out of 16545: 44 %
# Loading ham... 7281 out of 16545: 44 %
# Loading ham... 7282 out of 16545: 44 %
# Loading ham... 7283 out of 16545: 44 %
# Loading ham... 7284 out of 16545: 44 %
# Loading ham... 7285 out of 16545: 44 %
# Loading ham... 7286 out of 16545: 44 %
# Loading ham... 7287 out of 16545: 44 %
# Loading ham... 7288 out of 16545: 44 %
# Loading ham... 7289 out of 16545: 44 %
# Loading ham... 7290 out of 16545: 44 %
# Loading ham... 7291 out of 16545: 44 %
# Loading ham... 7292 out of 16545: 44 %
# Loading ham... 7293 out of 16545: 44 %
# Loading ham... 7294 out of 16545: 44 %
# Loading ham... 7295 out of 16545: 44 %
# Loading ham... 7296 out of 16545: 44 %
# Loading ham... 7297 out of 16545: 44 %
# Loading ham... 7298 out of 16545: 44 %
# Loading ham... 7299 out of 16545: 44 %
# Loading ham... 7300 out of 16545: 44 %
# Loading ham... 7301 out of 16545: 44 %
# Loading ham... 7302 out of 16545: 44 %
# Loading ham... 7303 out of 16545: 44 %
# Loading ham... 7304 out of 16545: 44 %
# Loading ham... 7305 out of 16545: 44 %
# Loading ham... 7306 out of 16545: 44 %
# Loading ham... 7307 out of 16545: 44 %
# Loading ham... 7308 out of 16545: 44 %
# Loading ham... 7309 out of 16545: 44 %
# Loading ham... 7310 out of 16545: 44 %
# Loading ham... 7311 out of 16545: 44 %
# Loading ham... 7312 out of 16545: 44 %
# Loading ham... 7313 out of 16545: 44 %
# Loading ham... 7314 out of 16545: 44 %
# Loading ham... 7315 out of 16545: 44 %
# Loading ham... 7316 out of 16545: 44 %
# Loading ham... 7317 out of 16545: 44 %
# Loading ham... 7318 out of 16545: 44 %
# Loading ham... 7319 out of 16545: 44 %
# Loading ham... 7320 out of 16545: 44 %
# Loading ham... 7321 out of 16545: 44 %
# Loading ham... 7322 out of 16545: 44 %
# Loading ham... 7323 out of 16545: 44 %
# Loading ham... 7324 out of 16545: 44 %
# Loading ham... 7325 out of 16545: 44 %
# Loading ham... 7326 out of 16545: 44 %
# Loading ham... 7327 out of 16545: 44 %
# Loading ham... 7328 out of 16545: 44 %
# Loading ham... 7329 out of 16545: 44 %
# Loading ham... 7330 out of 16545: 44 %
# Loading ham... 7331 out of 16545: 44 %
# Loading ham... 7332 out of 16545: 44 %
# Loading ham... 7333 out of 16545: 44 %
# Loading ham... 7334 out of 16545: 44 %
# Loading ham... 7335 out of 16545: 44 %
# Loading ham... 7336 out of 16545: 44 %
# Loading ham... 7337 out of 16545: 44 %
# Loading ham... 7338 out of 16545: 44 %
# Loading ham... 7339 out of 16545: 44 %
# Loading ham... 7340 out of 16545: 44 %
# Loading ham... 7341 out of 16545: 44 %
# Loading ham... 7342 out of 16545: 44 %
# Loading ham... 7343 out of 16545: 44 %
# Loading ham... 7344 out of 16545: 44 %
# Loading ham... 7345 out of 16545: 44 %
# Loading ham... 7346 out of 16545: 44 %
# Loading ham... 7347 out of 16545: 44 %
# Loading ham... 7348 out of 16545: 44 %
# Loading ham... 7349 out of 16545: 44 %
# Loading ham... 7350 out of 16545: 44 %
# Loading ham... 7351 out of 16545: 44 %
# Loading ham... 7352 out of 16545: 44 %
# Loading ham... 7353 out of 16545: 44 %
# Loading ham... 7354 out of 16545: 44 %
# Loading ham... 7355 out of 16545: 44 %
# Loading ham... 7356 out of 16545: 44 %
# Loading ham... 7357 out of 16545: 44 %
# Loading ham... 7358 out of 16545: 44 %
# Loading ham... 7359 out of 16545: 44 %
# Loading ham... 7360 out of 16545: 44 %
# Loading ham... 7361 out of 16545: 44 %
# Loading ham... 7362 out of 16545: 44 %
# Loading ham... 7363 out of 16545: 44 %
# Loading ham... 7364 out of 16545: 44 %
# Loading ham... 7365 out of 16545: 44 %
# Loading ham... 7366 out of 16545: 44 %
# Loading ham... 7367 out of 16545: 44 %
# Loading ham... 7368 out of 16545: 44 %
# Loading ham... 7369 out of 16545: 44 %
# Loading ham... 7370 out of 16545: 44 %
# Loading ham... 7371 out of 16545: 44 %
# Loading ham... 7372 out of 16545: 44 %
# Loading ham... 7373 out of 16545: 44 %
# Loading ham... 7374 out of 16545: 44 %
# Loading ham... 7375 out of 16545: 44 %
# Loading ham... 7376 out of 16545: 44 %
# Loading ham... 7377 out of 16545: 44 %
# Loading ham... 7378 out of 16545: 44 %
# Loading ham... 7379 out of 16545: 44 %
# Loading ham... 7380 out of 16545: 44 %
# Loading ham... 7381 out of 16545: 44 %
# Loading ham... 7382 out of 16545: 44 %
# Loading ham... 7383 out of 16545: 44 %
# Loading ham... 7384 out of 16545: 44 %
# Loading ham... 7385 out of 16545: 44 %
# Loading ham... 7386 out of 16545: 44 %
# Loading ham... 7387 out of 16545: 44 %
# Loading ham... 7388 out of 16545: 44 %
# Loading ham... 7389 out of 16545: 44 %
# Loading ham... 7390 out of 16545: 44 %
# Loading ham... 7391 out of 16545: 44 %
# Loading ham... 7392 out of 16545: 44 %
# Loading ham... 7393 out of 16545: 44 %
# Loading ham... 7394 out of 16545: 44 %
# Loading ham... 7395 out of 16545: 44 %
# Loading ham... 7396 out of 16545: 44 %
# Loading ham... 7397 out of 16545: 44 %
# Loading ham... 7398 out of 16545: 44 %
# Loading ham... 7399 out of 16545: 44 %
# Loading ham... 7400 out of 16545: 44 %
# Loading ham... 7401 out of 16545: 44 %
# Loading ham... 7402 out of 16545: 44 %
# Loading ham... 7403 out of 16545: 44 %
# Loading ham... 7404 out of 16545: 44 %
# Loading ham... 7405 out of 16545: 44 %
# Loading ham... 7406 out of 16545: 44 %
# Loading ham... 7407 out of 16545: 44 %
# Loading ham... 7408 out of 16545: 44 %
# Loading ham... 7409 out of 16545: 44 %
# Loading ham... 7410 out of 16545: 44 %
# Loading ham... 7411 out of 16545: 44 %
# Loading ham... 7412 out of 16545: 44 %
# Loading ham... 7413 out of 16545: 44 %
# Loading ham... 7414 out of 16545: 44 %
# Loading ham... 7415 out of 16545: 44 %
# Loading ham... 7416 out of 16545: 44 %
# Loading ham... 7417 out of 16545: 44 %
# Loading ham... 7418 out of 16545: 44 %
# Loading ham... 7419 out of 16545: 44 %
# Loading ham... 7420 out of 16545: 44 %
# Loading ham... 7421 out of 16545: 44 %
# Loading ham... 7422 out of 16545: 44 %
# Loading ham... 7423 out of 16545: 44 %
# Loading ham... 7424 out of 16545: 44 %
# Loading ham... 7425 out of 16545: 44 %
# Loading ham... 7426 out of 16545: 44 %
# Loading ham... 7427 out of 16545: 44 %
# Loading ham... 7428 out of 16545: 44 %
# Loading ham... 7429 out of 16545: 44 %
# Loading ham... 7430 out of 16545: 44 %
# Loading ham... 7431 out of 16545: 44 %
# Loading ham... 7432 out of 16545: 44 %
# Loading ham... 7433 out of 16545: 44 %
# Loading ham... 7434 out of 16545: 44 %
# Loading ham... 7435 out of 16545: 44 %
# Loading ham... 7436 out of 16545: 44 %
# Loading ham... 7437 out of 16545: 44 %
# Loading ham... 7438 out of 16545: 44 %
# Loading ham... 7439 out of 16545: 44 %
# Loading ham... 7440 out of 16545: 44 %
# Loading ham... 7441 out of 16545: 44 %
# Loading ham... 7442 out of 16545: 44 %
# Loading ham... 7443 out of 16545: 44 %
# Loading ham... 7444 out of 16545: 44 %
# Loading ham... 7445 out of 16545: 44 %
# Loading ham... 7446 out of 16545: 45 %
# Loading ham... 7447 out of 16545: 45 %
# Loading ham... 7448 out of 16545: 45 %
# Loading ham... 7449 out of 16545: 45 %
# Loading ham... 7450 out of 16545: 45 %
# Loading ham... 7451 out of 16545: 45 %
# Loading ham... 7452 out of 16545: 45 %
# Loading ham... 7453 out of 16545: 45 %
# Loading ham... 7454 out of 16545: 45 %
# Loading ham... 7455 out of 16545: 45 %
# Loading ham... 7456 out of 16545: 45 %
# Loading ham... 7457 out of 16545: 45 %
# Loading ham... 7458 out of 16545: 45 %
# Loading ham... 7459 out of 16545: 45 %
# Loading ham... 7460 out of 16545: 45 %
# Loading ham... 7461 out of 16545: 45 %
# Loading ham... 7462 out of 16545: 45 %
# Loading ham... 7463 out of 16545: 45 %
# Loading ham... 7464 out of 16545: 45 %
# Loading ham... 7465 out of 16545: 45 %
# Loading ham... 7466 out of 16545: 45 %
# Loading ham... 7467 out of 16545: 45 %
# Loading ham... 7468 out of 16545: 45 %
# Loading ham... 7469 out of 16545: 45 %
# Loading ham... 7470 out of 16545: 45 %
# Loading ham... 7471 out of 16545: 45 %
# Loading ham... 7472 out of 16545: 45 %
# Loading ham... 7473 out of 16545: 45 %
# Loading ham... 7474 out of 16545: 45 %
# Loading ham... 7475 out of 16545: 45 %
# Loading ham... 7476 out of 16545: 45 %
# Loading ham... 7477 out of 16545: 45 %
# Loading ham... 7478 out of 16545: 45 %
# Loading ham... 7479 out of 16545: 45 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-2f3d6c5c6471> in <module>
#      13         spam_collection = load_(a_files[1], "spam")
#      14     else:
# ---> 15         ham_collection, spam_collection = enron_selector()
#      16     dictionary = dictionary_build((ham_collection + spam_collection))
#      17     dictionary = dictionary.most_common(feature_size)
#
# <ipython-input-13-ad5298a7c5e6> in enron_selector()
#      31
#      32     spam = init_lists(spam, "spam")
# ---> 33     ham = init_lists(ham, "ham")
#      34     all_emails = [(email, 'spam') for email in spam]
#      35     all_emails += [(email, 'ham') for email in ham]
#
# <ipython-input-13-ad5298a7c5e6> in init_lists(folder_collection, label)
#      13         for a_file in file_list:
#      14             f = open(a_file, 'r')
# ---> 15             process_status(doc_id, file_list, label)
#      16             try:
#      17                 a_list.append(f.read())
#
# KeyboardInterrupt:
